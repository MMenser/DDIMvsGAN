# %% [markdown]
# <a href="https://colab.research.google.com/github/MMenser/DDIMvsGAN/blob/main/mason/DDIMFlowers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import math
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from datetime import datetime
import keras
from keras import layers
from keras import ops

# data
dataset_name = "oxford_flowers102"
dataset_repetitions = 5
num_epochs = 50  # train for at least 50 epochs for good results
image_size = 64
# KID = Kernel Inception Distance, see related section
kid_image_size = 299
kid_diffusion_steps = 20
plot_diffusion_steps = 20

# sampling
min_signal_rate = 0.02
max_signal_rate = 0.95

# architecture
embedding_dims = 32
embedding_max_frequency = 1000.0
widths = [32, 64, 96, 128]
block_depth = 2

# optimization
batch_size = 64
ema = 0.999
learning_rate = 1e-3
weight_decay = 1e-4


def preprocess_image(data):
    # center crop image
    height = ops.shape(data["image"])[0]
    width = ops.shape(data["image"])[1]
    crop_size = ops.minimum(height, width)
    image = tf.image.crop_to_bounding_box(
        data["image"],
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )

    # resize and clip
    # for image downsampling it is important to turn on antialiasing
    image = tf.image.resize(image, size=[image_size, image_size], antialias=True)
    return ops.clip(image / 255.0, 0.0, 1.0)


def prepare_dataset(split):
    # the validation dataset is shuffled as well, because data order matters
    # for the KID estimation
    return (
        tfds.load(dataset_name, split=split, shuffle_files=True)
        .map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
        .cache()
        .repeat(dataset_repetitions)
        .shuffle(10 * batch_size)
        .batch(batch_size, drop_remainder=True)
        .prefetch(buffer_size=tf.data.AUTOTUNE)
    )


# load dataset
train_dataset = prepare_dataset("train[:80%]+validation[:80%]+test[:80%]")
val_dataset = prepare_dataset("train[80%:]+validation[80%:]+test[80%:]")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/oxford_flowers102/2.1.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/oxford_flowers102/2.1.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.R2JX8R_2.1.1/oxford_flowers102-train.tfrecord…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.R2JX8R_2.1.1/oxford_flowers102-test.tfrecord*…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.R2JX8R_2.1.1/oxford_flowers102-validation.tfr…
# Dataset oxford_flowers102 downloaded and prepared to /root/tensorflow_datasets/oxford_flowers102/2.1.1. Subsequent calls will reuse this data.

# %%
class MetricsLogger(keras.callbacks.Callback):
    def __init__(self, filepath='training_metrics.csv'):
        super().__init__()
        self.filepath = filepath
        self.metrics_history = []
        self.epoch_start_time = None

    def on_epoch_begin(self, epoch, logs=None):
        import time
        self.epoch_start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        import time
        import csv

        logs = logs or {}

        # Calculate epoch duration
        epoch_time = time.time() - self.epoch_start_time if self.epoch_start_time else None

        # Save metrics for this epoch
        epoch_metrics = {'epoch': epoch}
        if epoch_time is not None:
            epoch_metrics['epoch_time'] = epoch_time
        epoch_metrics.update(logs)
        self.metrics_history.append(epoch_metrics)

        # Write to CSV
        with open(self.filepath, 'w', newline='') as f:
            if self.metrics_history:
                writer = csv.DictWriter(f, fieldnames=self.metrics_history[0].keys())
                writer.writeheader()
                writer.writerows(self.metrics_history)

        print(f"Metrics saved to {self.filepath} (Epoch time: {epoch_time:.2f}s)")

# %%
@keras.saving.register_keras_serializable()
def sinusoidal_embedding(x):
    embedding_min_frequency = 1.0
    frequencies = ops.exp(
        ops.linspace(
            ops.log(embedding_min_frequency),
            ops.log(embedding_max_frequency),
            embedding_dims // 2,
        )
    )
    angular_speeds = ops.cast(2.0 * math.pi * frequencies, "float32")
    embeddings = ops.concatenate(
        [ops.sin(angular_speeds * x), ops.cos(angular_speeds * x)], axis=3
    )
    return embeddings


def ResidualBlock(width):
    def apply(x):
        input_width = x.shape[3]
        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(width, kernel_size=1)(x)
        x = layers.BatchNormalization(center=False, scale=False)(x)
        x = layers.Conv2D(width, kernel_size=3, padding="same", activation="swish")(x)
        x = layers.Conv2D(width, kernel_size=3, padding="same")(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownBlock(width, block_depth):
    def apply(x):
        x, skips = x
        for _ in range(block_depth):
            x = ResidualBlock(width)(x)
            skips.append(x)
        x = layers.AveragePooling2D(pool_size=2)(x)
        return x

    return apply


def UpBlock(width, block_depth):
    def apply(x):
        x, skips = x
        x = layers.UpSampling2D(size=2, interpolation="bilinear")(x)
        for _ in range(block_depth):
            x = layers.Concatenate()([x, skips.pop()])
            x = ResidualBlock(width)(x)
        return x

    return apply


def get_network(image_size, widths, block_depth):
    noisy_images = keras.Input(shape=(image_size, image_size, 3))
    noise_variances = keras.Input(shape=(1, 1, 1))

    e = layers.Lambda(sinusoidal_embedding, output_shape=(1, 1, 32))(noise_variances)
    e = layers.UpSampling2D(size=image_size, interpolation="nearest")(e)

    x = layers.Conv2D(widths[0], kernel_size=1)(noisy_images)
    x = layers.Concatenate()([x, e])

    skips = []
    for width in widths[:-1]:
        x = DownBlock(width, block_depth)([x, skips])

    for _ in range(block_depth):
        x = ResidualBlock(widths[-1])(x)

    for width in reversed(widths[:-1]):
        x = UpBlock(width, block_depth)([x, skips])

    x = layers.Conv2D(3, kernel_size=1, kernel_initializer="zeros")(x)

    return keras.Model([noisy_images, noise_variances], x, name="residual_unet")

@keras.saving.register_keras_serializable()
class DiffusionModel(keras.Model):
    def __init__(self, image_size, widths, block_depth):
        super().__init__()

        self.normalizer = layers.Normalization()
        self.network = get_network(image_size, widths, block_depth)
        self.ema_network = keras.models.clone_model(self.network)

    def compile(self, **kwargs):
        super().compile(**kwargs)

        self.noise_loss_tracker = keras.metrics.Mean(name="n_loss")
        self.image_loss_tracker = keras.metrics.Mean(name="i_loss")
        self.kid = KID(name="kid")

    @property
    def metrics(self):
        return [self.noise_loss_tracker, self.image_loss_tracker, self.kid]

    def denormalize(self, images):
        # convert the pixel values back to 0-1 range
        images = self.normalizer.mean + images * self.normalizer.variance**0.5
        return ops.clip(images, 0.0, 1.0)

    def diffusion_schedule(self, diffusion_times):
        # diffusion times -> angles
        start_angle = ops.cast(ops.arccos(max_signal_rate), "float32")
        end_angle = ops.cast(ops.arccos(min_signal_rate), "float32")

        diffusion_angles = start_angle + diffusion_times * (end_angle - start_angle)

        # angles -> signal and noise rates
        signal_rates = ops.cos(diffusion_angles)
        noise_rates = ops.sin(diffusion_angles)
        # note that their squared sum is always: sin^2(x) + cos^2(x) = 1

        return noise_rates, signal_rates

    def denoise(self, noisy_images, noise_rates, signal_rates, training):
        # the exponential moving average weights are used at evaluation
        if training:
            network = self.network
        else:
            network = self.ema_network

        # predict noise component and calculate the image component using it
        pred_noises = network([noisy_images, noise_rates**2], training=training)
        pred_images = (noisy_images - noise_rates * pred_noises) / signal_rates

        return pred_noises, pred_images

    def reverse_diffusion(self, initial_noise, diffusion_steps):
        # reverse diffusion = sampling
        startingTime = time.time()
        num_images = initial_noise.shape[0]
        step_size = 1.0 / diffusion_steps

        # important line:
        # at the first sampling step, the "noisy image" is pure noise
        # but its signal rate is assumed to be nonzero (min_signal_rate)
        next_noisy_images = initial_noise
        for step in range(diffusion_steps):
            noisy_images = next_noisy_images

            # separate the current noisy image to its components
            diffusion_times = ops.ones((num_images, 1, 1, 1)) - step * step_size
            noise_rates, signal_rates = self.diffusion_schedule(diffusion_times)
            pred_noises, pred_images = self.denoise(
                noisy_images, noise_rates, signal_rates, training=False
            )
            # network used in eval mode

            # remix the predicted components using the next signal and noise rates
            next_diffusion_times = diffusion_times - step_size
            next_noise_rates, next_signal_rates = self.diffusion_schedule(
                next_diffusion_times
            )
            next_noisy_images = (
                next_signal_rates * pred_images + next_noise_rates * pred_noises
            )
            # this new noisy image will be used in the next step
        print(f"\nSampling Time: {time.time() - startingTime}")
        return pred_images

    def generate(self, num_images, diffusion_steps):
        # noise -> images -> denormalized images
        initial_noise = keras.random.normal(
            shape=(num_images, image_size, image_size, 3)
        )
        generated_images = self.reverse_diffusion(initial_noise, diffusion_steps)
        generated_images = self.denormalize(generated_images)
        return generated_images

    def train_step(self, images):
          # normalize images to have standard deviation of 1, like the noises
          images = self.normalizer(images, training=True)
          noises = keras.random.normal(shape=(batch_size, image_size, image_size, 3))

          # sample uniform random diffusion times
          diffusion_times = keras.random.uniform(
              shape=(batch_size, 1, 1, 1), minval=0.0, maxval=1.0
          )
          noise_rates, signal_rates = self.diffusion_schedule(diffusion_times)
          # mix the images with noises accordingly
          noisy_images = signal_rates * images + noise_rates * noises

          with tf.GradientTape() as tape:
              # train the network to separate noisy images to their components
              pred_noises, pred_images = self.denoise(
                  noisy_images, noise_rates, signal_rates, training=True
              )

              noise_loss = self.loss(noises, pred_noises)  # used for training
              image_loss = self.loss(images, pred_images)  # only used as metric

          gradients = tape.gradient(noise_loss, self.network.trainable_weights)
          self.optimizer.apply_gradients(zip(gradients, self.network.trainable_weights))

          self.noise_loss_tracker.update_state(noise_loss)
          self.image_loss_tracker.update_state(image_loss)

          # track the exponential moving averages of weights
          for weight, ema_weight in zip(self.network.weights, self.ema_network.weights):
              ema_weight.assign(ema * ema_weight + (1 - ema) * weight)

          # KID is not measured during the training phase for computational efficiency
          return {m.name: m.result() for m in self.metrics[:-1]}

    def test_step(self, images):
        # normalize images to have standard deviation of 1, like the noises
        images = self.normalizer(images, training=False)
        noises = keras.random.normal(shape=(batch_size, image_size, image_size, 3))

        # sample uniform random diffusion times
        diffusion_times = keras.random.uniform(
            shape=(batch_size, 1, 1, 1), minval=0.0, maxval=1.0
        )
        noise_rates, signal_rates = self.diffusion_schedule(diffusion_times)
        # mix the images with noises accordingly
        noisy_images = signal_rates * images + noise_rates * noises

        # use the network to separate noisy images to their components
        pred_noises, pred_images = self.denoise(
            noisy_images, noise_rates, signal_rates, training=False
        )

        noise_loss = self.loss(noises, pred_noises)
        image_loss = self.loss(images, pred_images)

        self.image_loss_tracker.update_state(image_loss)
        self.noise_loss_tracker.update_state(noise_loss)

        # measure KID between real and generated images
        # this is computationally demanding, kid_diffusion_steps has to be small
        images = self.denormalize(images)
        generated_images = self.generate(
            num_images=batch_size, diffusion_steps=kid_diffusion_steps
        )
        self.kid.update_state(images, generated_images)

        return {m.name: m.result() for m in self.metrics}

    def plot_images(self, epoch=None, logs=None, num_rows=4, num_cols=4):
        # Create output directory if it doesn't exist
        output_dir = "generated_images"
        os.makedirs(output_dir, exist_ok=True)

        # Generate images
        generated_images = self.generate(
            num_images=num_rows * num_cols,
            diffusion_steps=plot_diffusion_steps,
        )

        # Plot grid
        plt.figure(figsize=(num_cols * 2.0, num_rows * 2.0))
        for row in range(num_rows):
            for col in range(num_cols):
                index = row * num_cols + col
                plt.subplot(num_rows, num_cols, index + 1)
                plt.imshow(generated_images[index])
                plt.axis("off")
        plt.tight_layout()

        # Save figure
        timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
        filename = f"epoch_{epoch:03d}_{timestamp}.png" if epoch is not None else f"sample_{timestamp}.png"
        filepath = os.path.join(output_dir, filename)
        plt.savefig(filepath)
        plt.close()

        print(f"Saved generated images to {filepath}")

# %%
@keras.saving.register_keras_serializable()
class KID(keras.metrics.Metric):
    def __init__(self, name, **kwargs):
        super().__init__(name=name, **kwargs)

        # KID is estimated per batch and is averaged across batches
        self.kid_tracker = keras.metrics.Mean(name="kid_tracker")

        # a pretrained InceptionV3 is used without its classification layer
        # transform the pixel values to the 0-255 range, then use the same
        # preprocessing as during pretraining
        self.encoder = keras.Sequential(
            [
                keras.Input(shape=(image_size, image_size, 3)),
                layers.Rescaling(255.0),
                layers.Resizing(height=kid_image_size, width=kid_image_size),
                layers.Lambda(keras.applications.inception_v3.preprocess_input),
                keras.applications.InceptionV3(
                    include_top=False,
                    input_shape=(kid_image_size, kid_image_size, 3),
                    weights="imagenet",
                ),
                layers.GlobalAveragePooling2D(),
            ],
            name="inception_encoder",
        )

    def polynomial_kernel(self, features_1, features_2):
        feature_dimensions = ops.cast(ops.shape(features_1)[1], dtype="float32")
        return (
            features_1 @ ops.transpose(features_2) / feature_dimensions + 1.0
        ) ** 3.0

    def update_state(self, real_images, generated_images, sample_weight=None):
        real_features = self.encoder(real_images, training=False)
        generated_features = self.encoder(generated_images, training=False)

        # compute polynomial kernels using the two sets of features
        kernel_real = self.polynomial_kernel(real_features, real_features)
        kernel_generated = self.polynomial_kernel(
            generated_features, generated_features
        )
        kernel_cross = self.polynomial_kernel(real_features, generated_features)

        # estimate the squared maximum mean discrepancy using the average kernel values
        batch_size = real_features.shape[0]
        batch_size_f = ops.cast(batch_size, dtype="float32")
        mean_kernel_real = ops.sum(kernel_real * (1.0 - ops.eye(batch_size))) / (
            batch_size_f * (batch_size_f - 1.0)
        )
        mean_kernel_generated = ops.sum(
            kernel_generated * (1.0 - ops.eye(batch_size))
        ) / (batch_size_f * (batch_size_f - 1.0))
        mean_kernel_cross = ops.mean(kernel_cross)
        kid = mean_kernel_real + mean_kernel_generated - 2.0 * mean_kernel_cross

        # update the average KID estimate
        self.kid_tracker.update_state(kid)

    def result(self):
        return self.kid_tracker.result()

    def reset_state(self):
        self.kid_tracker.reset_state()

# %%
# create and compile the model
model = DiffusionModel(image_size, widths, block_depth)
metrics_logger = MetricsLogger(filepath='training_metrics.csv')  # Add this line

model.compile(
    optimizer=keras.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    ),
    loss=keras.losses.mean_absolute_error,
)
# pixelwise mean absolute error is used as loss

# save the best model based on the validation KID metric
checkpoint_path = "checkpoints/diffusion_model.weights.h5"
checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_kid",
    mode="min",
    save_best_only=True,
)

# calculate mean and variance of training dataset for normalization
model.normalizer.adapt(train_dataset)

# Build model explicitly before training to avoid "not yet built" error
dummy_images = tf.zeros((1, image_size, image_size, 3))
dummy_times = tf.zeros((1, 1, 1, 1))
_ = model.network([dummy_images, dummy_times])  # build inner UNet
_ = model.ema_network([dummy_images, dummy_times])  # build EMA network
model.built = True
print("Model built.")

# run training and plot generated images periodically
model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=val_dataset,
    callbacks=[
        keras.callbacks.LambdaCallback(on_epoch_end=model.plot_images),
        checkpoint_callback,
        metrics_logger,
    ],
)
# Out:
# Model built.
# Epoch 1/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - i_loss: 0.6954 - n_loss: 0.2874
# Sampling Time: 10.278163194656372
#
# Sampling Time: 2.2150096893310547
# Saved generated images to generated_images/epoch_000_20251129-182709.png
# Metrics saved to training_metrics.csv (Epoch time: 111.22s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 111s 166ms/step - i_loss: 0.6949 - n_loss: 0.2872 - val_i_loss: 2.4534 - val_kid: 0.5459 - val_n_loss: 0.7905
# Epoch 2/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2923 - n_loss: 0.1706
# Sampling Time: 2.186948537826538
# Saved generated images to generated_images/epoch_001_20251129-182754.png
# Metrics saved to training_metrics.csv (Epoch time: 43.77s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2923 - n_loss: 0.1706 - val_i_loss: 2.2197 - val_kid: 0.5495 - val_n_loss: 0.7241
# Epoch 3/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2742 - n_loss: 0.1625
# Sampling Time: 2.231452226638794
# Saved generated images to generated_images/epoch_002_20251129-182838.png
# Metrics saved to training_metrics.csv (Epoch time: 43.83s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2742 - n_loss: 0.1625 - val_i_loss: 1.7109 - val_kid: 0.5483 - val_n_loss: 0.5982
# Epoch 4/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2637 - n_loss: 0.1586
# Sampling Time: 2.1964380741119385
# Saved generated images to generated_images/epoch_003_20251129-182921.png
# Metrics saved to training_metrics.csv (Epoch time: 44.98s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2637 - n_loss: 0.1586 - val_i_loss: 1.3057 - val_kid: 0.5122 - val_n_loss: 0.4564
# Epoch 5/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2605 - n_loss: 0.1561
# Sampling Time: 2.2097010612487793
# Saved generated images to generated_images/epoch_004_20251129-183007.png
# Metrics saved to training_metrics.csv (Epoch time: 45.02s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2605 - n_loss: 0.1561 - val_i_loss: 0.9155 - val_kid: 0.4787 - val_n_loss: 0.3374
# Epoch 6/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2571 - n_loss: 0.1537
# Sampling Time: 2.202124834060669
# Saved generated images to generated_images/epoch_005_20251129-183051.png
# Metrics saved to training_metrics.csv (Epoch time: 44.94s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2571 - n_loss: 0.1537 - val_i_loss: 0.6205 - val_kid: 0.4744 - val_n_loss: 0.2536
# Epoch 7/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2538 - n_loss: 0.1528
# Sampling Time: 2.196969985961914
# Saved generated images to generated_images/epoch_006_20251129-183136.png
# Metrics saved to training_metrics.csv (Epoch time: 44.92s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2538 - n_loss: 0.1528 - val_i_loss: 0.4514 - val_kid: 0.3390 - val_n_loss: 0.2011
# Epoch 8/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2504 - n_loss: 0.1521
# Sampling Time: 2.188110113143921
# Saved generated images to generated_images/epoch_007_20251129-183221.png
# Metrics saved to training_metrics.csv (Epoch time: 44.97s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2504 - n_loss: 0.1521 - val_i_loss: 0.3403 - val_kid: 0.2356 - val_n_loss: 0.1736
# Epoch 9/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2483 - n_loss: 0.1509
# Sampling Time: 2.2181761264801025
# Saved generated images to generated_images/epoch_008_20251129-183307.png
# Metrics saved to training_metrics.csv (Epoch time: 46.04s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 46s 90ms/step - i_loss: 0.2483 - n_loss: 0.1509 - val_i_loss: 0.2889 - val_kid: 0.1696 - val_n_loss: 0.1584
# Epoch 10/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - i_loss: 0.2472 - n_loss: 0.1500
# Sampling Time: 2.2152342796325684
# Saved generated images to generated_images/epoch_009_20251129-183353.png
# Metrics saved to training_metrics.csv (Epoch time: 45.31s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 89ms/step - i_loss: 0.2472 - n_loss: 0.1500 - val_i_loss: 0.2594 - val_kid: 0.1140 - val_n_loss: 0.1510
# Epoch 11/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2470 - n_loss: 0.1492
# Sampling Time: 2.189260959625244
# Saved generated images to generated_images/epoch_010_20251129-183438.png
# Metrics saved to training_metrics.csv (Epoch time: 45.14s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2470 - n_loss: 0.1492 - val_i_loss: 0.2485 - val_kid: 0.0805 - val_n_loss: 0.1477
# Epoch 12/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - i_loss: 0.2437 - n_loss: 0.1490
# Sampling Time: 2.1928937435150146
# Saved generated images to generated_images/epoch_011_20251129-183523.png
# Metrics saved to training_metrics.csv (Epoch time: 45.23s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 89ms/step - i_loss: 0.2437 - n_loss: 0.1490 - val_i_loss: 0.2402 - val_kid: 0.0664 - val_n_loss: 0.1456
# Epoch 13/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2451 - n_loss: 0.1486
# Sampling Time: 2.1836395263671875
# Saved generated images to generated_images/epoch_012_20251129-183608.png
# Metrics saved to training_metrics.csv (Epoch time: 45.10s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2451 - n_loss: 0.1486 - val_i_loss: 0.2338 - val_kid: 0.0618 - val_n_loss: 0.1469
# Epoch 14/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - i_loss: 0.2437 - n_loss: 0.1482
# Sampling Time: 2.1990387439727783
# Saved generated images to generated_images/epoch_013_20251129-183653.png
# Metrics saved to training_metrics.csv (Epoch time: 45.15s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2437 - n_loss: 0.1482 - val_i_loss: 0.2348 - val_kid: 0.0597 - val_n_loss: 0.1446
# Epoch 15/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2427 - n_loss: 0.1477
# Sampling Time: 2.186124086380005
# Saved generated images to generated_images/epoch_014_20251129-183739.png
# Metrics saved to training_metrics.csv (Epoch time: 45.11s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2427 - n_loss: 0.1477 - val_i_loss: 0.2335 - val_kid: 0.0585 - val_n_loss: 0.1441
# Epoch 16/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2435 - n_loss: 0.1478
# Sampling Time: 2.200869560241699
# Saved generated images to generated_images/epoch_015_20251129-183824.png
# Metrics saved to training_metrics.csv (Epoch time: 45.10s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2435 - n_loss: 0.1478 - val_i_loss: 0.2328 - val_kid: 0.0574 - val_n_loss: 0.1448
# Epoch 17/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2414 - n_loss: 0.1470
# Sampling Time: 2.21120023727417
# Saved generated images to generated_images/epoch_016_20251129-183909.png
# Metrics saved to training_metrics.csv (Epoch time: 45.15s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2414 - n_loss: 0.1470 - val_i_loss: 0.2317 - val_kid: 0.0567 - val_n_loss: 0.1442
# Epoch 18/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2395 - n_loss: 0.1473
# Sampling Time: 2.1800172328948975
# Saved generated images to generated_images/epoch_017_20251129-183954.png
# Metrics saved to training_metrics.csv (Epoch time: 45.09s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2395 - n_loss: 0.1473 - val_i_loss: 0.2317 - val_kid: 0.0553 - val_n_loss: 0.1445
# Epoch 19/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - i_loss: 0.2432 - n_loss: 0.1458
# Sampling Time: 2.184340238571167
# Saved generated images to generated_images/epoch_018_20251129-184039.png
# Metrics saved to training_metrics.csv (Epoch time: 44.00s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2432 - n_loss: 0.1458 - val_i_loss: 0.2315 - val_kid: 0.0560 - val_n_loss: 0.1439
# Epoch 20/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - i_loss: 0.2396 - n_loss: 0.1466
# Sampling Time: 2.1936404705047607
# Saved generated images to generated_images/epoch_019_20251129-184123.png
# Metrics saved to training_metrics.csv (Epoch time: 45.09s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2396 - n_loss: 0.1466 - val_i_loss: 0.2289 - val_kid: 0.0551 - val_n_loss: 0.1458
# Epoch 21/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2386 - n_loss: 0.1460
# Sampling Time: 2.1914398670196533
# Saved generated images to generated_images/epoch_020_20251129-184208.png
# Metrics saved to training_metrics.csv (Epoch time: 45.10s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2386 - n_loss: 0.1460 - val_i_loss: 0.2306 - val_kid: 0.0548 - val_n_loss: 0.1433
# Epoch 22/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2406 - n_loss: 0.1459
# Sampling Time: 2.188657760620117
# Saved generated images to generated_images/epoch_021_20251129-184253.png
# Metrics saved to training_metrics.csv (Epoch time: 45.07s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2406 - n_loss: 0.1459 - val_i_loss: 0.2297 - val_kid: 0.0537 - val_n_loss: 0.1448
# Epoch 23/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2381 - n_loss: 0.1455
# Sampling Time: 2.1699256896972656
# Saved generated images to generated_images/epoch_022_20251129-184338.png
# Metrics saved to training_metrics.csv (Epoch time: 45.05s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2381 - n_loss: 0.1455 - val_i_loss: 0.2336 - val_kid: 0.0532 - val_n_loss: 0.1429
# Epoch 24/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2380 - n_loss: 0.1461
# Sampling Time: 2.203301191329956
# Saved generated images to generated_images/epoch_023_20251129-184423.png
# Metrics saved to training_metrics.csv (Epoch time: 45.06s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2380 - n_loss: 0.1461 - val_i_loss: 0.2290 - val_kid: 0.0519 - val_n_loss: 0.1434
# Epoch 25/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2383 - n_loss: 0.1451
# Sampling Time: 2.1950643062591553
# Saved generated images to generated_images/epoch_024_20251129-184508.png
# Metrics saved to training_metrics.csv (Epoch time: 43.94s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2383 - n_loss: 0.1451 - val_i_loss: 0.2321 - val_kid: 0.0527 - val_n_loss: 0.1429
# Epoch 26/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2378 - n_loss: 0.1455
# Sampling Time: 2.1869492530822754
# Saved generated images to generated_images/epoch_025_20251129-184552.png
# Metrics saved to training_metrics.csv (Epoch time: 43.83s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2378 - n_loss: 0.1455 - val_i_loss: 0.2258 - val_kid: 0.0525 - val_n_loss: 0.1451
# Epoch 27/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2381 - n_loss: 0.1457
# Sampling Time: 2.204355478286743
# Saved generated images to generated_images/epoch_026_20251129-184636.png
# Metrics saved to training_metrics.csv (Epoch time: 43.97s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2381 - n_loss: 0.1457 - val_i_loss: 0.2282 - val_kid: 0.0526 - val_n_loss: 0.1437
# Epoch 28/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2361 - n_loss: 0.1456
# Sampling Time: 2.1929755210876465
# Saved generated images to generated_images/epoch_027_20251129-184720.png
# Metrics saved to training_metrics.csv (Epoch time: 43.89s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2361 - n_loss: 0.1456 - val_i_loss: 0.2268 - val_kid: 0.0536 - val_n_loss: 0.1439
# Epoch 29/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2354 - n_loss: 0.1457
# Sampling Time: 2.170135498046875
# Saved generated images to generated_images/epoch_028_20251129-184805.png
# Metrics saved to training_metrics.csv (Epoch time: 45.07s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2354 - n_loss: 0.1457 - val_i_loss: 0.2290 - val_kid: 0.0528 - val_n_loss: 0.1432
# Epoch 30/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2378 - n_loss: 0.1446
# Sampling Time: 2.2161598205566406
# Saved generated images to generated_images/epoch_029_20251129-184849.png
# Metrics saved to training_metrics.csv (Epoch time: 44.90s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2378 - n_loss: 0.1446 - val_i_loss: 0.2294 - val_kid: 0.0508 - val_n_loss: 0.1433
# Epoch 31/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2377 - n_loss: 0.1443
# Sampling Time: 2.192256212234497
# Saved generated images to generated_images/epoch_030_20251129-184934.png
# Metrics saved to training_metrics.csv (Epoch time: 44.87s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2377 - n_loss: 0.1443 - val_i_loss: 0.2288 - val_kid: 0.0495 - val_n_loss: 0.1427
# Epoch 32/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2362 - n_loss: 0.1450
# Sampling Time: 2.1660091876983643
# Saved generated images to generated_images/epoch_031_20251129-185019.png
# Metrics saved to training_metrics.csv (Epoch time: 43.80s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2362 - n_loss: 0.1450 - val_i_loss: 0.2273 - val_kid: 0.0500 - val_n_loss: 0.1439
# Epoch 33/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2360 - n_loss: 0.1445
# Sampling Time: 2.1950864791870117
# Saved generated images to generated_images/epoch_032_20251129-185103.png
# Metrics saved to training_metrics.csv (Epoch time: 43.69s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2360 - n_loss: 0.1445 - val_i_loss: 0.2288 - val_kid: 0.0502 - val_n_loss: 0.1432
# Epoch 34/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2350 - n_loss: 0.1446
# Sampling Time: 2.1722965240478516
# Saved generated images to generated_images/epoch_033_20251129-185146.png
# Metrics saved to training_metrics.csv (Epoch time: 44.89s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 45s 88ms/step - i_loss: 0.2350 - n_loss: 0.1446 - val_i_loss: 0.2290 - val_kid: 0.0495 - val_n_loss: 0.1424
# Epoch 35/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2350 - n_loss: 0.1444
# Sampling Time: 2.1771912574768066
# Saved generated images to generated_images/epoch_034_20251129-185231.png
# Metrics saved to training_metrics.csv (Epoch time: 43.70s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2350 - n_loss: 0.1444 - val_i_loss: 0.2293 - val_kid: 0.0500 - val_n_loss: 0.1422
# Epoch 36/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2359 - n_loss: 0.1443
# Sampling Time: 2.1833622455596924
# Saved generated images to generated_images/epoch_035_20251129-185315.png
# Metrics saved to training_metrics.csv (Epoch time: 43.78s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2359 - n_loss: 0.1443 - val_i_loss: 0.2284 - val_kid: 0.0495 - val_n_loss: 0.1425
# Epoch 37/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2372 - n_loss: 0.1438
# Sampling Time: 2.15968656539917
# Saved generated images to generated_images/epoch_036_20251129-185359.png
# Metrics saved to training_metrics.csv (Epoch time: 43.74s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2372 - n_loss: 0.1438 - val_i_loss: 0.2314 - val_kid: 0.0515 - val_n_loss: 0.1413
# Epoch 38/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2341 - n_loss: 0.1449
# Sampling Time: 2.217942953109741
# Saved generated images to generated_images/epoch_037_20251129-185442.png
# Metrics saved to training_metrics.csv (Epoch time: 43.73s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2341 - n_loss: 0.1449 - val_i_loss: 0.2285 - val_kid: 0.0503 - val_n_loss: 0.1434
# Epoch 39/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2356 - n_loss: 0.1435
# Sampling Time: 2.2036900520324707
# Saved generated images to generated_images/epoch_038_20251129-185526.png
# Metrics saved to training_metrics.csv (Epoch time: 43.69s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2356 - n_loss: 0.1435 - val_i_loss: 0.2285 - val_kid: 0.0512 - val_n_loss: 0.1429
# Epoch 40/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2338 - n_loss: 0.1438
# Sampling Time: 2.180636167526245
# Saved generated images to generated_images/epoch_039_20251129-185610.png
# Metrics saved to training_metrics.csv (Epoch time: 43.68s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2338 - n_loss: 0.1438 - val_i_loss: 0.2276 - val_kid: 0.0498 - val_n_loss: 0.1434
# Epoch 41/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2346 - n_loss: 0.1439
# Sampling Time: 2.166182279586792
# Saved generated images to generated_images/epoch_040_20251129-185653.png
# Metrics saved to training_metrics.csv (Epoch time: 43.68s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2346 - n_loss: 0.1439 - val_i_loss: 0.2295 - val_kid: 0.0498 - val_n_loss: 0.1428
# Epoch 42/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2328 - n_loss: 0.1446
# Sampling Time: 2.1487467288970947
# Saved generated images to generated_images/epoch_041_20251129-185737.png
# Metrics saved to training_metrics.csv (Epoch time: 43.60s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 85ms/step - i_loss: 0.2328 - n_loss: 0.1446 - val_i_loss: 0.2284 - val_kid: 0.0516 - val_n_loss: 0.1428
# Epoch 43/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2381 - n_loss: 0.1423
# Sampling Time: 2.209148406982422
# Saved generated images to generated_images/epoch_042_20251129-185821.png
# Metrics saved to training_metrics.csv (Epoch time: 43.70s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2381 - n_loss: 0.1423 - val_i_loss: 0.2302 - val_kid: 0.0509 - val_n_loss: 0.1420
# Epoch 44/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2337 - n_loss: 0.1437
# Sampling Time: 2.1689584255218506
# Saved generated images to generated_images/epoch_043_20251129-185904.png
# Metrics saved to training_metrics.csv (Epoch time: 43.68s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2337 - n_loss: 0.1437 - val_i_loss: 0.2282 - val_kid: 0.0501 - val_n_loss: 0.1426
# Epoch 45/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2347 - n_loss: 0.1433
# Sampling Time: 2.177504777908325
# Saved generated images to generated_images/epoch_044_20251129-185948.png
# Metrics saved to training_metrics.csv (Epoch time: 43.66s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2347 - n_loss: 0.1433 - val_i_loss: 0.2281 - val_kid: 0.0496 - val_n_loss: 0.1423
# Epoch 46/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2363 - n_loss: 0.1428
# Sampling Time: 2.197571039199829
# Saved generated images to generated_images/epoch_045_20251129-190032.png
# Metrics saved to training_metrics.csv (Epoch time: 43.72s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2363 - n_loss: 0.1428 - val_i_loss: 0.2303 - val_kid: 0.0504 - val_n_loss: 0.1416
# Epoch 47/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2335 - n_loss: 0.1431
# Sampling Time: 2.1719510555267334
# Saved generated images to generated_images/epoch_046_20251129-190116.png
# Metrics saved to training_metrics.csv (Epoch time: 43.67s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2335 - n_loss: 0.1431 - val_i_loss: 0.2284 - val_kid: 0.0500 - val_n_loss: 0.1426
# Epoch 48/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2349 - n_loss: 0.1431
# Sampling Time: 2.2133960723876953
# Saved generated images to generated_images/epoch_047_20251129-190159.png
# Metrics saved to training_metrics.csv (Epoch time: 43.77s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2349 - n_loss: 0.1431 - val_i_loss: 0.2292 - val_kid: 0.0517 - val_n_loss: 0.1423
# Epoch 49/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - i_loss: 0.2356 - n_loss: 0.1425
# Sampling Time: 2.217155694961548
# Saved generated images to generated_images/epoch_048_20251129-190243.png
# Metrics saved to training_metrics.csv (Epoch time: 43.91s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2356 - n_loss: 0.1425 - val_i_loss: 0.2297 - val_kid: 0.0511 - val_n_loss: 0.1422
# Epoch 50/50
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - i_loss: 0.2353 - n_loss: 0.1418
# Sampling Time: 2.1684584617614746
# Saved generated images to generated_images/epoch_049_20251129-190327.png
# Metrics saved to training_metrics.csv (Epoch time: 43.91s)
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - i_loss: 0.2353 - n_loss: 0.1418 - val_i_loss: 0.2269 - val_kid: 0.0507 - val_n_loss: 0.1426

# %%
import shutil
from google.colab import files

# Replace 'my_folder' with the actual name of the folder you want to download
# The first argument is the name of the zip file to be created (without extension)
# The second argument is the format ('zip', 'tar', etc.)
# The third argument is the path to the folder you want to compress
shutil.make_archive("my_folder_archive", 'zip', "generated_images")
# Out:
# '/content/my_folder_archive.zip'

# %%
# Replace 'my_folder_archive.zip' with the name of the zip file you created
files.download("my_folder_archive.zip")
