# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from datetime import datetime
import keras
from keras import layers, ops
import numpy as np
import pandas as pd
import time

# %%
# Hyperparameters
dataset_name = "oxford_flowers102"
dataset_repetitions = 5
num_epochs = 50
image_size = 64
batch_size = 64
latent_dim = 100

# WGAN specific
critic_iterations = 5  # Train critic 5 times per generator update
clip_value = 0.01  # Weight clipping value for WGAN
learning_rate = 5e-5  # Lower learning rate for WGAN stability

# %%
def preprocess_image(data):
    """Preprocess image: center crop, resize, normalize to [0, 1]"""
    height = ops.shape(data["image"])[0]
    width = ops.shape(data["image"])[1]
    crop_size = ops.minimum(height, width)
    image = tf.image.crop_to_bounding_box(
        data["image"],
        (height - crop_size) // 2,
        (width - crop_size) // 2,
        crop_size,
        crop_size,
    )
    image = tf.image.resize(image, size=[image_size, image_size], antialias=True)
    return ops.clip(image / 255.0, 0.0, 1.0)


def prepare_dataset(split):
    """Prepare dataset with preprocessing and batching"""
    return (
        tfds.load(dataset_name, split=split, shuffle_files=True)
        .map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
        .cache()
        .repeat(dataset_repetitions)
        .shuffle(10 * batch_size)
        .batch(batch_size, drop_remainder=True)
        .prefetch(buffer_size=tf.data.AUTOTUNE)
    )


# Use validation for KID (Flowers102 has train/validation/test)
kid_val_ds = prepare_dataset("validation")
kid_val_iter = iter(kid_val_ds)  # we’ll sample from this in training

# %%
class KIDMetric(keras.metrics.Metric):
    """
    Unbiased KID (Kernel Inception Distance) with polynomial kernel of degree 3.
    KID = E[k(x,x')] + E[k(y,y')] - 2E[k(x,y)], x=real features, y=fake features
    Uses InceptionV3 (avg pooled) as the encoder.
    """
    def __init__(self, image_size=64, kid_image_size=299, name="kid", **kwargs):
        super().__init__(name=name, **kwargs)
        self.kid_tracker = keras.metrics.Mean(name="kid_tracker")
        self.kid_image_size = kid_image_size

        # Inception encoder: [0,1] -> [0,255] -> preprocess_input -> InceptionV3 -> GAP(2048)
        self.encoder = keras.Sequential(
            [
                keras.Input(shape=(image_size, image_size, 3)),
                layers.Rescaling(255.0),
                layers.Resizing(kid_image_size, kid_image_size),
                layers.Lambda(keras.applications.inception_v3.preprocess_input),
                keras.applications.InceptionV3(
                    include_top=False,
                    input_shape=(kid_image_size, kid_image_size, 3),
                    weights="imagenet",
                ),
                layers.GlobalAveragePooling2D(),
            ],
            name="inception_encoder",
        )

    def polynomial_kernel(self, feats1, feats2):
        # k(x,y) = (xᵀy / d + 1)^3
        d = ops.cast(ops.shape(feats1)[1], "float32")
        return (feats1 @ ops.transpose(feats2) / d + 1.0) ** 3.0

    def _unbiased_mmd(self, f_real, f_fake):
        # Gram matrices
        k_xx = self.polynomial_kernel(f_real, f_real)
        k_yy = self.polynomial_kernel(f_fake, f_fake)
        k_xy = self.polynomial_kernel(f_real, f_fake)

        m = tf.shape(f_real)[0]
        n = tf.shape(f_fake)[0]

        # remove diagonal terms for unbiased estimate
        sum_k_xx = (tf.reduce_sum(k_xx) - tf.reduce_sum(tf.linalg.diag_part(k_xx))) / tf.cast(m * (m - 1), tf.float32)
        sum_k_yy = (tf.reduce_sum(k_yy) - tf.reduce_sum(tf.linalg.diag_part(k_yy))) / tf.cast(n * (n - 1), tf.float32)
        sum_k_xy = tf.reduce_sum(k_xy) / tf.cast(m * n, tf.float32)

        return sum_k_xx + sum_k_yy - 2.0 * sum_k_xy

    def update_state(self, real_images, generated_images, sample_weight=None):
        # Expect inputs in [0,1]. If your generator outputs [-1,1] via tanh,
        # convert: gen = (gen + 1.0) / 2.0 before calling update_state.
        f_real = self.encoder(real_images, training=False)
        f_fake = self.encoder(generated_images, training=False)
        kid = self._unbiased_mmd(f_real, f_fake)
        self.kid_tracker.update_state(kid)

    def result(self):
        return self.kid_tracker.result()

    def reset_state(self):
        self.kid_tracker.reset_state()

# --- KID generation helper ---
latent_dim = 100  # keep whatever your WGAN uses

def gen_fake_batch(generator, batch_size):
    z = tf.random.normal(shape=(batch_size, latent_dim))
    fake = generator(z, training=False)
    # Map to [0,1] if your generator uses tanh output in [-1,1]
    if fake.dtype.is_floating:
        # Heuristic: if values look like tanh, rescale
        # (safe to always rescale if you know you're using tanh)
        fake = (fake + 1.0) / 2.0
    return tf.clip_by_value(fake, 0.0, 1.0)

# %%
# Load datasets
train_dataset = prepare_dataset("train[:80%]+validation[:80%]+test[:80%]")
# Print out a sample of the dataset
for image in train_dataset.take(1):
    plt.imshow(image[0].numpy())
    plt.show()
    break


def build_generator(latent_dim, image_size):
    """Build generator network"""
    model = keras.Sequential([
        keras.Input(shape=(latent_dim,)),
        layers.Dense(4 * 4 * 256, use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),
        layers.Reshape((4, 4, 256)),

        layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),

        layers.Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),

        layers.Conv2DTranspose(32, (4, 4), strides=(2, 2), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),

        layers.Conv2DTranspose(3, (4, 4), strides=(2, 2), padding='same', use_bias=False),
        layers.Activation('tanh'),  # Output in [-1, 1]
    ], name='generator')
    return model


def build_critic(image_size):
    """WGAN-GP critic: no BatchNorm/Dropout; plain conv stack."""
    L = keras.layers
    x = inputs = keras.Input(shape=(image_size, image_size, 3))
    nf = 64
    # 64 -> 32
    x = L.Conv2D(nf, 4, strides=2, padding="same", kernel_initializer="he_normal")(x)
    x = L.LeakyReLU(0.2)(x)
    # 32 -> 16
    x = L.Conv2D(nf*2, 4, strides=2, padding="same", kernel_initializer="he_normal")(x)
    x = L.LeakyReLU(0.2)(x)
    # 16 -> 8
    x = L.Conv2D(nf*4, 4, strides=2, padding="same", kernel_initializer="he_normal")(x)
    x = L.LeakyReLU(0.2)(x)
    # 8 -> 4
    x = L.Conv2D(nf*8, 4, strides=2, padding="same", kernel_initializer="he_normal")(x)
    x = L.LeakyReLU(0.2)(x)

    x = L.Flatten()(x)
    out = L.Dense(1)(x)  # linear score
    return keras.Model(inputs, out, name="critic")

# Gradient penalty hyperparam
gp_lambda = 10.0

def gradient_penalty(critic, real, fake):
    """WGAN-GP gradient penalty on random interpolates"""
    batch = tf.shape(real)[0]
    epsilon = tf.random.uniform([batch, 1, 1, 1], 0.0, 1.0)
    x_hat = epsilon * real + (1.0 - epsilon) * fake
    with tf.GradientTape() as gp_tape:
        gp_tape.watch(x_hat)
        pred = critic(x_hat, training=True)
    grads = gp_tape.gradient(pred, x_hat)  # ∂D/∂x_hat
    grads = tf.reshape(grads, [batch, -1])
    grad_norm = tf.norm(grads, axis=1)
    gp = tf.reduce_mean((grad_norm - 1.0) ** 2)
    return gp


def generate_images(generator, epoch, num_images=16):
    """Generate and save sample images"""
    # Generate random noise
    noise = tf.random.normal((num_images, latent_dim))

    # Generate images
    generated_images = G_ema(noise, training=False)

    # Convert from [-1, 1] to [0, 1] for display
    generated_images = (generated_images + 1) / 2.0
    generated_images = ops.clip(generated_images, 0.0, 1.0)

    # Create output directory
    output_dir = "generated_images"
    os.makedirs(output_dir, exist_ok=True)

    # Plot grid
    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    for i, ax in enumerate(axes.flat):
        ax.imshow(generated_images[i].numpy())
        ax.axis('off')
    plt.tight_layout()

    # Save figure
    timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
    filename = f"epoch_{epoch:03d}_{timestamp}.png"
    filepath = os.path.join(output_dir, filename)
    plt.savefig(filepath)
    plt.close()

    print(f"Saved generated images to {filepath}")

# Helper function for ema
def update_ema(G_src, G_tgt, decay=0.999):
    """G_tgt = EMA(G_src)  (in-place)"""
    src_w = G_src.get_weights()
    tgt_w = G_tgt.get_weights()
    new_w = []
    for w_ema, w in zip(tgt_w, src_w):
        new_w.append(decay * w_ema + (1.0 - decay) * w)
    G_tgt.set_weights(new_w)

# %%
# Build models
generator = build_generator(latent_dim, image_size)
critic = build_critic(image_size)

# --- EMA setup (place right after you build `generator`) ---
G_ema = keras.models.clone_model(generator)
G_ema.set_weights(generator.get_weights())
ema_decay = 0.999  # try 0.999 for 50 epochs; 0.9995 if you train longer

# Optimizers - Adam instead of RMSProp
generator_optimizer = keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.0, beta_2=0.9)
critic_optimizer    = keras.optimizers.Adam(learning_rate=1e-4, beta_1=0.0, beta_2=0.9)

print("Generator summary:")
generator.summary()
print("\nCritic summary:")
critic.summary()


# Training step
@tf.function
def train_step(real_images):
    batch_size = tf.shape(real_images)[0]
    real_images = real_images * 2.0 - 1.0  # [-1,1]

    # --- Critic updates ---
    for _ in range(critic_iterations):
        noise = tf.random.normal((batch_size, latent_dim))
        fake_images = generator(noise, training=True)  # training=True OK

        with tf.GradientTape() as tape:
            real_scores = critic(real_images, training=True)
            fake_scores = critic(fake_images, training=True)

            wasserstein = tf.reduce_mean(real_scores) - tf.reduce_mean(fake_scores)
            gp = gradient_penalty(critic, real_images, fake_images)
            # We minimize the negative of wasserstein + GP term
            critic_loss = -(wasserstein) + gp_lambda * gp

        grads = tape.gradient(critic_loss, critic.trainable_weights)
        critic_optimizer.apply_gradients(zip(grads, critic.trainable_weights))

    # --- Generator update ---
    noise = tf.random.normal((batch_size, latent_dim))
    with tf.GradientTape() as tape:
        fake_images = generator(noise, training=True)
        fake_scores = critic(fake_images, training=True)  # train mode since no BN/Dropout
        generator_loss = -tf.reduce_mean(fake_scores)
    g_grads = tape.gradient(generator_loss, generator.trainable_weights)
    generator_optimizer.apply_gradients(zip(g_grads, generator.trainable_weights))

    # For logging, you might also return components:
    return critic_loss, generator_loss, wasserstein, gp


# --- Initialize KID metric ---
kid_metric = KIDMetric(image_size=image_size, kid_image_size=299)
kid_history = []

# Create validation iterator (already defined above)
kid_val_iter = iter(kid_val_ds)



# Training loop + KID eval (per epoch)
print("\nStarting training...")

# Start overall timing
training_start_time = time.time()

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch + 1}/{num_epochs}")

    # Start epoch timing
    epoch_start_time = time.time()

    epoch_critic_loss = []
    epoch_generator_loss = []

    for step, batch_images in enumerate(train_dataset):
        critic_loss, generator_loss, W, gp_val = train_step(batch_images)
        update_ema(generator, G_ema, decay=ema_decay)

        epoch_critic_loss.append(critic_loss.numpy())
        epoch_generator_loss.append(generator_loss.numpy())

        if step % 100 == 0:
            print(
                f"  Step {step}: D_loss={critic_loss:.4f} G_loss={generator_loss:.4f} "
                f"W={W:.4f} GP={gp_val:.4f}"
            )

    # Epoch training time
    epoch_train_time = time.time() - epoch_start_time

    # Print epoch averages
    avg_critic_loss = np.mean(epoch_critic_loss)
    avg_generator_loss = np.mean(epoch_generator_loss)
    print(
        f"  Epoch {epoch + 1} - Avg Critic Loss: {avg_critic_loss:.4f}, "
        f"Avg Generator Loss: {avg_generator_loss:.4f}"
    )

    # --------- KID EVAL (every epoch) ----------
    print(f"  Computing KID for epoch {epoch + 1}...")
    kid_start_time = time.time()

    # Get a real batch from validation split
    try:
        real_eval = next(kid_val_iter)
    except StopIteration:
        kid_val_iter = iter(kid_val_ds)
        real_eval = next(kid_val_iter)

    # Generate a fake batch using EMA generator
    fake_eval = gen_fake_batch(G_ema, tf.shape(real_eval)[0])

    # Update KID and log it
    kid_metric.update_state(real_eval, fake_eval)
    current_kid = float(kid_metric.result().numpy())
    kid_eval_time = time.time() - kid_start_time

    kid_history.append({
        "epoch": int(epoch + 1),
        "kid": current_kid,
        "epoch_train_time_sec": epoch_train_time,
        "kid_eval_time_sec": kid_eval_time,
        "avg_critic_loss": float(avg_critic_loss),
        "avg_generator_loss": float(avg_generator_loss)
    })

    print(f"  [KID] Epoch {epoch+1}: KID={current_kid:.6f} (eval time: {kid_eval_time:.2f}s)")
    kid_metric.reset_state()
    # ------------------------------------------------------

    # Generate and save sample images every epoch
    sampling_start_time = time.time()
    generate_images(generator, epoch + 1)
    sampling_time = time.time() - sampling_start_time

    # Update history with sampling time
    kid_history[-1]["sampling_time_sec"] = sampling_time

    print(f"  Epoch time: {epoch_train_time:.2f}s, Sampling time: {sampling_time:.2f}s")
# Out:
# Generator summary:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 4096)           │       409,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_294         │ (None, 4096)           │        16,384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_24 (LeakyReLU)      │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_3 (Reshape)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_12             │ (None, 8, 8, 128)      │       524,288 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_295         │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_25 (LeakyReLU)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_13             │ (None, 16, 16, 64)     │       131,072 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_296         │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_26 (LeakyReLU)      │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_14             │ (None, 32, 32, 32)     │        32,768 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_297         │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_27 (LeakyReLU)      │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_15             │ (None, 64, 64, 3)      │         1,536 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_285 (Activation)     │ (None, 64, 64, 3)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,116,544 (4.26 MB)
#  Trainable params: 1,107,904 (4.23 MB)
#  Non-trainable params: 8,640 (33.75 KB)
# Critic summary:
# Model: "critic"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)     │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_294 (Conv2D)             │ (None, 32, 32, 64)     │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_28 (LeakyReLU)      │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_295 (Conv2D)             │ (None, 16, 16, 128)    │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_29 (LeakyReLU)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_296 (Conv2D)             │ (None, 8, 8, 256)      │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_30 (LeakyReLU)      │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_297 (Conv2D)             │ (None, 4, 4, 512)      │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_31 (LeakyReLU)      │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │         8,193 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,764,737 (10.55 MB)
#  Trainable params: 2,764,737 (10.55 MB)
#  Non-trainable params: 0 (0.00 B)
# Starting training...
#
# Epoch 1/50
#   Step 0: D_loss=-8.2971 G_loss=3.8514 W=9.3789 GP=0.1082
#   Step 100: D_loss=-40.8743 G_loss=-29.3287 W=56.8747 GP=1.6000
#   Step 200: D_loss=-19.0801 G_loss=-23.0566 W=23.1768 GP=0.4097
#   Step 300: D_loss=-15.9825 G_loss=24.9729 W=18.7978 GP=0.2815
#   Step 400: D_loss=-19.7209 G_loss=14.2806 W=25.4378 GP=0.5717
#   Step 500: D_loss=-17.3273 G_loss=2.3815 W=20.8256 GP=0.3498
#   Epoch 1 - Avg Critic Loss: -27.9242, Avg Generator Loss: -3.8364
#   Computing KID for epoch 1...
#   [KID] Epoch 1: KID=0.507913 (eval time: 1.04s)
# Saved generated images to generated_images/epoch_001_20251120-232721.png
#   Epoch time: 72.70s, Sampling time: 0.31s
#
# Epoch 2/50
#   Step 0: D_loss=-16.6727 G_loss=-11.4692 W=20.0798 GP=0.3407
#   Step 100: D_loss=-17.9473 G_loss=-2.5315 W=22.9732 GP=0.5026
#   Step 200: D_loss=-17.5530 G_loss=2.6546 W=21.6012 GP=0.4048
#   Step 300: D_loss=-14.9929 G_loss=-11.0958 W=18.1659 GP=0.3173
#   Step 400: D_loss=-13.8170 G_loss=-5.0333 W=17.9441 GP=0.4127
#   Step 500: D_loss=-16.2064 G_loss=-15.8104 W=19.4362 GP=0.3230
#   Epoch 2 - Avg Critic Loss: -16.1725, Avg Generator Loss: -7.7294
#   Computing KID for epoch 2...
#   [KID] Epoch 2: KID=0.460712 (eval time: 0.64s)
# Saved generated images to generated_images/epoch_002_20251120-232823.png
#   Epoch time: 61.55s, Sampling time: 0.31s
#
# Epoch 3/50
#   Step 0: D_loss=-17.3416 G_loss=-43.9828 W=21.8658 GP=0.4524
#   Step 100: D_loss=-14.0981 G_loss=-32.4175 W=17.3049 GP=0.3207
#   Step 200: D_loss=-13.4827 G_loss=-17.3279 W=15.9594 GP=0.2477
#   Step 300: D_loss=-13.6167 G_loss=-21.0379 W=16.6838 GP=0.3067
#   Step 400: D_loss=-16.2590 G_loss=-15.4771 W=19.3099 GP=0.3051
#   Step 500: D_loss=-14.8881 G_loss=-30.9614 W=17.2620 GP=0.2374
#   Epoch 3 - Avg Critic Loss: -14.6498, Avg Generator Loss: -17.0523
#   Computing KID for epoch 3...
#   [KID] Epoch 3: KID=0.448729 (eval time: 0.64s)
# Saved generated images to generated_images/epoch_003_20251120-232926.png
#   Epoch time: 61.55s, Sampling time: 0.31s
#
# Epoch 4/50
#   Step 0: D_loss=-13.9112 G_loss=-27.6170 W=16.3466 GP=0.2435
#   Step 100: D_loss=-14.5545 G_loss=-9.8360 W=16.7945 GP=0.2240
#   Step 200: D_loss=-15.7896 G_loss=-47.3154 W=17.9591 GP=0.2169
#   Step 300: D_loss=-13.2870 G_loss=-13.9590 W=15.9000 GP=0.2613
#   Step 400: D_loss=-12.0528 G_loss=-19.7006 W=14.7989 GP=0.2746
#   Step 500: D_loss=-14.5094 G_loss=-4.3208 W=17.4844 GP=0.2975
#   Epoch 4 - Avg Critic Loss: -14.0105, Avg Generator Loss: -20.9792
#   Computing KID for epoch 4...
#   [KID] Epoch 4: KID=0.322049 (eval time: 0.64s)
# Saved generated images to generated_images/epoch_004_20251120-233028.png
#   Epoch time: 61.79s, Sampling time: 0.31s
#
# Epoch 5/50
#   Step 0: D_loss=-13.0105 G_loss=-16.2885 W=15.3918 GP=0.2381
#   Step 100: D_loss=-13.5363 G_loss=-46.9695 W=15.9712 GP=0.2435
#   Step 200: D_loss=-15.4026 G_loss=-24.7414 W=20.3995 GP=0.4997
#   Step 300: D_loss=-12.1214 G_loss=-13.1588 W=14.3294 GP=0.2208
#   Step 400: D_loss=-14.2787 G_loss=-46.6427 W=17.0955 GP=0.2817
#   Step 500: D_loss=-14.2564 G_loss=3.8580 W=16.4834 GP=0.2227
#   Epoch 5 - Avg Critic Loss: -13.5334, Avg Generator Loss: -21.6079
#   Computing KID for epoch 5...
#   [KID] Epoch 5: KID=0.272658 (eval time: 0.63s)
# Saved generated images to generated_images/epoch_005_20251120-233131.png
#   Epoch time: 61.72s, Sampling time: 0.31s
#
# Epoch 6/50
#   Step 0: D_loss=-12.8245 G_loss=-22.2962 W=14.9644 GP=0.2140
#   Step 100: D_loss=-15.4331 G_loss=-11.8711 W=18.3091 GP=0.2876
#   Step 200: D_loss=-14.0233 G_loss=-32.6357 W=16.3555 GP=0.2332
#   Step 300: D_loss=-15.0997 G_loss=-21.3464 W=18.5482 GP=0.3448
#   Step 400: D_loss=-14.1541 G_loss=-11.3450 W=16.4175 GP=0.2263
#   Step 500: D_loss=-12.5514 G_loss=-10.4998 W=14.1692 GP=0.1618
#   Epoch 6 - Avg Critic Loss: -13.3274, Avg Generator Loss: -20.8229
#   Computing KID for epoch 6...
#   [KID] Epoch 6: KID=0.260604 (eval time: 0.61s)
# Saved generated images to generated_images/epoch_006_20251120-233233.png
#   Epoch time: 61.33s, Sampling time: 0.31s
#
# Epoch 7/50
#   Step 0: D_loss=-13.9425 G_loss=-30.0282 W=15.9787 GP=0.2036
#   Step 100: D_loss=-15.8188 G_loss=-28.0447 W=18.8210 GP=0.3002
#   Step 200: D_loss=-10.1046 G_loss=-25.4306 W=12.2801 GP=0.2176
#   Step 300: D_loss=-14.0373 G_loss=-19.5548 W=16.5368 GP=0.2500
#   Step 400: D_loss=-13.7492 G_loss=-22.0857 W=15.5493 GP=0.1800
#   Step 500: D_loss=-12.3528 G_loss=-22.1476 W=14.8762 GP=0.2523
#   Epoch 7 - Avg Critic Loss: -13.3927, Avg Generator Loss: -18.7551
#   Computing KID for epoch 7...
#   [KID] Epoch 7: KID=0.231537 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_007_20251120-233336.png
#   Epoch time: 61.47s, Sampling time: 0.31s
#
# Epoch 8/50
#   Step 0: D_loss=-12.3058 G_loss=-10.4921 W=13.9624 GP=0.1657
#   Step 100: D_loss=-14.7515 G_loss=-26.0290 W=17.5072 GP=0.2756
#   Step 200: D_loss=-12.9262 G_loss=-16.5287 W=15.5934 GP=0.2667
#   Step 300: D_loss=-14.5596 G_loss=-47.7044 W=17.4595 GP=0.2900
#   Step 400: D_loss=-15.7479 G_loss=-13.0794 W=17.8378 GP=0.2090
#   Step 500: D_loss=-12.8491 G_loss=-29.1792 W=14.5436 GP=0.1695
#   Epoch 8 - Avg Critic Loss: -13.2855, Avg Generator Loss: -16.2230
#   Computing KID for epoch 8...
#   [KID] Epoch 8: KID=0.259480 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_008_20251120-233438.png
#   Epoch time: 61.19s, Sampling time: 0.31s
#
# Epoch 9/50
#   Step 0: D_loss=-13.1229 G_loss=-5.4200 W=16.0634 GP=0.2941
#   Step 100: D_loss=-12.8964 G_loss=-22.0617 W=14.9990 GP=0.2103
#   Step 200: D_loss=-17.2467 G_loss=-13.6391 W=21.7544 GP=0.4508
#   Step 300: D_loss=-14.8061 G_loss=-32.1006 W=18.2448 GP=0.3439
#   Step 400: D_loss=-12.4255 G_loss=-29.1644 W=14.0601 GP=0.1635
#   Step 500: D_loss=-12.0029 G_loss=-7.9284 W=13.5820 GP=0.1579
#   Epoch 9 - Avg Critic Loss: -13.1587, Avg Generator Loss: -13.0417
#   Computing KID for epoch 9...
#   [KID] Epoch 9: KID=0.255276 (eval time: 0.61s)
# Saved generated images to generated_images/epoch_009_20251120-233540.png
#   Epoch time: 61.51s, Sampling time: 0.31s
#
# Epoch 10/50
#   Step 0: D_loss=-12.0653 G_loss=-18.6336 W=13.6546 GP=0.1589
#   Step 100: D_loss=-11.6257 G_loss=-9.6881 W=13.1396 GP=0.1514
#   Step 200: D_loss=-12.4407 G_loss=-16.7539 W=14.4202 GP=0.1980
#   Step 300: D_loss=-13.7112 G_loss=7.4950 W=16.0676 GP=0.2356
#   Step 400: D_loss=-12.1358 G_loss=-3.1927 W=13.8578 GP=0.1722
#   Step 500: D_loss=-11.2507 G_loss=-9.1564 W=12.7724 GP=0.1522
#   Epoch 10 - Avg Critic Loss: -13.0561, Avg Generator Loss: -10.4335
#   Computing KID for epoch 10...
#   [KID] Epoch 10: KID=0.249773 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_010_20251120-233643.png
#   Epoch time: 62.02s, Sampling time: 0.32s
#
# Epoch 11/50
#   Step 0: D_loss=-13.7477 G_loss=12.6128 W=15.7727 GP=0.2025
#   Step 100: D_loss=-13.7986 G_loss=-9.2101 W=17.9164 GP=0.4118
#   Step 200: D_loss=-14.8647 G_loss=-9.1325 W=18.0750 GP=0.3210
#   Step 300: D_loss=-13.5153 G_loss=-17.3663 W=16.7583 GP=0.3243
#   Step 400: D_loss=-14.3450 G_loss=-24.9128 W=16.8493 GP=0.2504
#   Step 500: D_loss=-12.0081 G_loss=-9.4726 W=14.1003 GP=0.2092
#   Epoch 11 - Avg Critic Loss: -13.0592, Avg Generator Loss: -7.3033
#   Computing KID for epoch 11...
#   [KID] Epoch 11: KID=0.243297 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_011_20251120-233746.png
#   Epoch time: 61.59s, Sampling time: 0.82s
#
# Epoch 12/50
#   Step 0: D_loss=-12.6090 G_loss=-1.0531 W=14.6257 GP=0.2017
#   Step 100: D_loss=-12.3101 G_loss=-17.5305 W=14.3052 GP=0.1995
#   Step 200: D_loss=-16.9085 G_loss=-16.9413 W=20.1607 GP=0.3252
#   Step 300: D_loss=-13.3094 G_loss=-5.4822 W=15.6632 GP=0.2354
#   Step 400: D_loss=-14.2741 G_loss=-5.2170 W=16.0670 GP=0.1793
#   Step 500: D_loss=-13.8937 G_loss=-14.2672 W=15.7325 GP=0.1839
#   Epoch 12 - Avg Critic Loss: -13.1983, Avg Generator Loss: -6.6253
#   Computing KID for epoch 12...
#   [KID] Epoch 12: KID=0.257715 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_012_20251120-233849.png
#   Epoch time: 61.36s, Sampling time: 0.32s
#
# Epoch 13/50
#   Step 0: D_loss=-10.7884 G_loss=-3.5619 W=12.3941 GP=0.1606
#   Step 100: D_loss=-12.6344 G_loss=-8.2317 W=14.3820 GP=0.1748
#   Step 200: D_loss=-15.8373 G_loss=-18.5346 W=19.3213 GP=0.3484
#   Step 300: D_loss=-12.1849 G_loss=6.9339 W=14.9146 GP=0.2730
#   Step 400: D_loss=-12.9814 G_loss=-11.9045 W=15.3407 GP=0.2359
#   Step 500: D_loss=-14.6705 G_loss=-0.0825 W=18.1799 GP=0.3509
#   Epoch 13 - Avg Critic Loss: -13.3327, Avg Generator Loss: -6.0754
#   Computing KID for epoch 13...
#   [KID] Epoch 13: KID=0.230212 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_013_20251120-233951.png
#   Epoch time: 61.30s, Sampling time: 0.31s
#
# Epoch 14/50
#   Step 0: D_loss=-12.9891 G_loss=-10.7753 W=15.5254 GP=0.2536
#   Step 100: D_loss=-14.5606 G_loss=-4.9176 W=17.0784 GP=0.2518
#   Step 200: D_loss=-14.8089 G_loss=-1.0400 W=17.6766 GP=0.2868
#   Step 300: D_loss=-12.0540 G_loss=-2.8369 W=13.9410 GP=0.1887
#   Step 400: D_loss=-11.9685 G_loss=1.1192 W=15.0796 GP=0.3111
#   Step 500: D_loss=-13.8127 G_loss=3.6206 W=15.9894 GP=0.2177
#   Epoch 14 - Avg Critic Loss: -13.3088, Avg Generator Loss: -4.3169
#   Computing KID for epoch 14...
#   [KID] Epoch 14: KID=0.246495 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_014_20251120-234054.png
#   Epoch time: 61.75s, Sampling time: 0.31s
#
# Epoch 15/50
#   Step 0: D_loss=-15.2020 G_loss=-26.2952 W=17.9734 GP=0.2771
#   Step 100: D_loss=-12.1772 G_loss=-17.8049 W=14.2897 GP=0.2113
#   Step 200: D_loss=-12.9238 G_loss=5.4517 W=15.0649 GP=0.2141
#   Step 300: D_loss=-11.6931 G_loss=-11.0176 W=13.6822 GP=0.1989
#   Step 400: D_loss=-13.5846 G_loss=-15.0060 W=15.9652 GP=0.2381
#   Step 500: D_loss=-13.6326 G_loss=-5.3810 W=15.9666 GP=0.2334
#   Epoch 15 - Avg Critic Loss: -13.4036, Avg Generator Loss: -3.9186
#   Computing KID for epoch 15...
#   [KID] Epoch 15: KID=0.237143 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_015_20251120-234156.png
#   Epoch time: 61.80s, Sampling time: 0.31s
#
# Epoch 16/50
#   Step 0: D_loss=-13.9386 G_loss=3.0954 W=16.1735 GP=0.2235
#   Step 100: D_loss=-13.4518 G_loss=-5.4290 W=15.7018 GP=0.2250
#   Step 200: D_loss=-14.9096 G_loss=-5.6764 W=17.5503 GP=0.2641
#   Step 300: D_loss=-13.2575 G_loss=-5.1465 W=15.6959 GP=0.2438
#   Step 400: D_loss=-11.1456 G_loss=-4.5979 W=12.9527 GP=0.1807
#   Step 500: D_loss=-11.8952 G_loss=-13.3723 W=15.2634 GP=0.3368
#   Epoch 16 - Avg Critic Loss: -13.5729, Avg Generator Loss: -3.8388
#   Computing KID for epoch 16...
#   [KID] Epoch 16: KID=0.232809 (eval time: 0.63s)
# Saved generated images to generated_images/epoch_016_20251120-234259.png
#   Epoch time: 61.84s, Sampling time: 0.31s
#
# Epoch 17/50
#   Step 0: D_loss=-12.2944 G_loss=-10.4011 W=15.0515 GP=0.2757
#   Step 100: D_loss=-15.5292 G_loss=-18.4425 W=18.6989 GP=0.3170
#   Step 200: D_loss=-13.1067 G_loss=-3.6341 W=16.2181 GP=0.3111
#   Step 300: D_loss=-13.7235 G_loss=8.1408 W=16.0000 GP=0.2276
#   Step 400: D_loss=-13.7681 G_loss=3.0643 W=16.8356 GP=0.3067
#   Step 500: D_loss=-14.4913 G_loss=1.7033 W=17.6687 GP=0.3177
#   Epoch 17 - Avg Critic Loss: -13.6590, Avg Generator Loss: -3.8960
#   Computing KID for epoch 17...
#   [KID] Epoch 17: KID=0.231569 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_017_20251120-234402.png
#   Epoch time: 61.66s, Sampling time: 0.32s
#
# Epoch 18/50
#   Step 0: D_loss=-12.1698 G_loss=10.3455 W=13.9285 GP=0.1759
#   Step 100: D_loss=-12.6454 G_loss=-2.7380 W=15.0249 GP=0.2379
#   Step 200: D_loss=-14.5085 G_loss=-17.5207 W=16.9923 GP=0.2484
#   Step 300: D_loss=-12.2200 G_loss=-2.1218 W=14.2244 GP=0.2004
#   Step 400: D_loss=-13.6608 G_loss=8.1181 W=15.8030 GP=0.2142
#   Step 500: D_loss=-13.9437 G_loss=-10.5281 W=17.2014 GP=0.3258
#   Epoch 18 - Avg Critic Loss: -13.7603, Avg Generator Loss: -3.5888
#   Computing KID for epoch 18...
#   [KID] Epoch 18: KID=0.226959 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_018_20251120-234504.png
#   Epoch time: 61.39s, Sampling time: 0.31s
#
# Epoch 19/50
#   Step 0: D_loss=-14.6991 G_loss=-9.2627 W=17.2360 GP=0.2537
#   Step 100: D_loss=-13.5335 G_loss=11.6016 W=15.7324 GP=0.2199
#   Step 200: D_loss=-14.9254 G_loss=17.7426 W=18.2196 GP=0.3294
#   Step 300: D_loss=-13.4802 G_loss=-3.9723 W=15.6201 GP=0.2140
#   Step 400: D_loss=-12.6100 G_loss=-0.5873 W=14.5199 GP=0.1910
#   Step 500: D_loss=-12.7548 G_loss=4.4927 W=15.5613 GP=0.2807
#   Epoch 19 - Avg Critic Loss: -14.0121, Avg Generator Loss: -2.9052
#   Computing KID for epoch 19...
#   [KID] Epoch 19: KID=0.201353 (eval time: 0.61s)
# Saved generated images to generated_images/epoch_019_20251120-234607.png
#   Epoch time: 61.80s, Sampling time: 0.31s
#
# Epoch 20/50
#   Step 0: D_loss=-14.0454 G_loss=-3.5267 W=16.5214 GP=0.2476
#   Step 100: D_loss=-12.3949 G_loss=-1.2083 W=14.2017 GP=0.1807
#   Step 200: D_loss=-15.5670 G_loss=2.9959 W=18.1735 GP=0.2607
#   Step 300: D_loss=-14.0659 G_loss=-1.1135 W=15.9185 GP=0.1853
#   Step 400: D_loss=-17.2386 G_loss=11.0651 W=21.4469 GP=0.4208
#   Step 500: D_loss=-13.8469 G_loss=-8.0007 W=15.9519 GP=0.2105
#   Epoch 20 - Avg Critic Loss: -14.1373, Avg Generator Loss: -2.4805
#   Computing KID for epoch 20...
#   [KID] Epoch 20: KID=0.205704 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_020_20251120-234709.png
#   Epoch time: 61.67s, Sampling time: 0.31s
#
# Epoch 21/50
#   Step 0: D_loss=-13.3702 G_loss=-0.6748 W=15.2750 GP=0.1905
#   Step 100: D_loss=-14.0307 G_loss=-2.2081 W=15.8393 GP=0.1809
#   Step 200: D_loss=-13.3054 G_loss=8.2446 W=16.0282 GP=0.2723
#   Step 300: D_loss=-12.3992 G_loss=0.6764 W=14.2125 GP=0.1813
#   Step 400: D_loss=-18.0700 G_loss=-13.4677 W=23.3448 GP=0.5275
#   Step 500: D_loss=-15.4139 G_loss=-0.4719 W=18.1552 GP=0.2741
#   Epoch 21 - Avg Critic Loss: -14.1807, Avg Generator Loss: -1.4752
#   Computing KID for epoch 21...
#   [KID] Epoch 21: KID=0.208839 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_021_20251120-234812.png
#   Epoch time: 61.66s, Sampling time: 0.31s
#
# Epoch 22/50
#   Step 0: D_loss=-12.9101 G_loss=-2.0696 W=15.0785 GP=0.2168
#   Step 100: D_loss=-15.6818 G_loss=-6.8446 W=19.5350 GP=0.3853
#   Step 200: D_loss=-14.0641 G_loss=-2.2162 W=15.8769 GP=0.1813
#   Step 300: D_loss=-17.5009 G_loss=2.1832 W=20.1264 GP=0.2626
#   Step 400: D_loss=-17.4380 G_loss=-22.9086 W=20.5940 GP=0.3156
#   Step 500: D_loss=-15.8510 G_loss=-18.8397 W=19.2256 GP=0.3375
#   Epoch 22 - Avg Critic Loss: -14.3441, Avg Generator Loss: -1.7042
#   Computing KID for epoch 22...
#   [KID] Epoch 22: KID=0.183422 (eval time: 0.61s)
# Saved generated images to generated_images/epoch_022_20251120-234914.png
#   Epoch time: 61.28s, Sampling time: 0.31s
#
# Epoch 23/50
#   Step 0: D_loss=-14.5500 G_loss=-2.7141 W=17.1667 GP=0.2617
#   Step 100: D_loss=-14.5266 G_loss=-14.9975 W=16.9323 GP=0.2406
#   Step 200: D_loss=-15.4523 G_loss=-2.7378 W=17.7367 GP=0.2284
#   Step 300: D_loss=-13.5848 G_loss=2.1582 W=16.0717 GP=0.2487
#   Step 400: D_loss=-12.4746 G_loss=4.1563 W=14.5127 GP=0.2038
#   Step 500: D_loss=-15.1173 G_loss=-4.7402 W=17.6888 GP=0.2572
#   Epoch 23 - Avg Critic Loss: -14.4930, Avg Generator Loss: -1.9861
#   Computing KID for epoch 23...
#   [KID] Epoch 23: KID=0.194468 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_023_20251120-235016.png
#   Epoch time: 61.46s, Sampling time: 0.31s
#
# Epoch 24/50
#   Step 0: D_loss=-15.2621 G_loss=-8.4566 W=18.3502 GP=0.3088
#   Step 100: D_loss=-14.4562 G_loss=6.2797 W=17.0312 GP=0.2575
#   Step 200: D_loss=-14.2935 G_loss=-0.4279 W=17.5766 GP=0.3283
#   Step 300: D_loss=-14.5494 G_loss=-4.8600 W=16.6663 GP=0.2117
#   Step 400: D_loss=-13.2243 G_loss=1.5925 W=15.9857 GP=0.2761
#   Step 500: D_loss=-14.3985 G_loss=0.8592 W=17.2586 GP=0.2860
#   Epoch 24 - Avg Critic Loss: -14.7144, Avg Generator Loss: -1.5999
#   Computing KID for epoch 24...
#   [KID] Epoch 24: KID=0.197937 (eval time: 0.63s)
# Saved generated images to generated_images/epoch_024_20251120-235120.png
#   Epoch time: 61.49s, Sampling time: 0.94s
#
# Epoch 25/50
#   Step 0: D_loss=-13.5542 G_loss=3.6305 W=15.9054 GP=0.2351
#   Step 100: D_loss=-14.6036 G_loss=-12.0958 W=17.6744 GP=0.3071
#   Step 200: D_loss=-14.9749 G_loss=0.5404 W=17.2691 GP=0.2294
#   Step 300: D_loss=-16.3979 G_loss=-4.3421 W=19.7107 GP=0.3313
#   Step 400: D_loss=-15.3904 G_loss=-12.7313 W=17.6644 GP=0.2274
#   Step 500: D_loss=-15.7159 G_loss=-19.2773 W=18.6363 GP=0.2920
#   Epoch 25 - Avg Critic Loss: -14.9194, Avg Generator Loss: -2.0306
#   Computing KID for epoch 25...
#   [KID] Epoch 25: KID=0.207337 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_025_20251120-235222.png
#   Epoch time: 61.61s, Sampling time: 0.31s
#
# Epoch 26/50
#   Step 0: D_loss=-13.0258 G_loss=-11.9128 W=15.1005 GP=0.2075
#   Step 100: D_loss=-13.6527 G_loss=-7.6229 W=15.5783 GP=0.1926
#   Step 200: D_loss=-17.7869 G_loss=-11.7462 W=22.0248 GP=0.4238
#   Step 300: D_loss=-15.4854 G_loss=-6.3306 W=18.0446 GP=0.2559
#   Step 400: D_loss=-16.5328 G_loss=-10.4193 W=19.7558 GP=0.3223
#   Step 500: D_loss=-15.8487 G_loss=-8.2340 W=18.5368 GP=0.2688
#   Epoch 26 - Avg Critic Loss: -15.1564, Avg Generator Loss: -3.3426
#   Computing KID for epoch 26...
#   [KID] Epoch 26: KID=0.180901 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_026_20251120-235324.png
#   Epoch time: 61.35s, Sampling time: 0.31s
#
# Epoch 27/50
#   Step 0: D_loss=-12.8442 G_loss=9.3737 W=14.8137 GP=0.1969
#   Step 100: D_loss=-15.0728 G_loss=-12.8155 W=17.6889 GP=0.2616
#   Step 200: D_loss=-16.5962 G_loss=-8.1653 W=20.3403 GP=0.3744
#   Step 300: D_loss=-13.9774 G_loss=-10.4791 W=16.7609 GP=0.2784
#   Step 400: D_loss=-14.7398 G_loss=-11.8886 W=17.0459 GP=0.2306
#   Step 500: D_loss=-14.4503 G_loss=-2.8911 W=17.0389 GP=0.2589
#   Epoch 27 - Avg Critic Loss: -15.3170, Avg Generator Loss: -3.9717
#   Computing KID for epoch 27...
#   [KID] Epoch 27: KID=0.197367 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_027_20251120-235427.png
#   Epoch time: 61.43s, Sampling time: 0.31s
#
# Epoch 28/50
#   Step 0: D_loss=-19.7963 G_loss=-13.9069 W=23.3237 GP=0.3527
#   Step 100: D_loss=-14.1074 G_loss=0.6895 W=16.5653 GP=0.2458
#   Step 200: D_loss=-18.7057 G_loss=-16.9057 W=22.6325 GP=0.3927
#   Step 300: D_loss=-15.0010 G_loss=-5.6142 W=17.2692 GP=0.2268
#   Step 400: D_loss=-14.5250 G_loss=-16.6183 W=17.9107 GP=0.3386
#   Step 500: D_loss=-13.6295 G_loss=3.2904 W=16.3498 GP=0.2720
#   Epoch 28 - Avg Critic Loss: -15.4126, Avg Generator Loss: -4.8123
#   Computing KID for epoch 28...
#   [KID] Epoch 28: KID=0.183221 (eval time: 0.61s)
# Saved generated images to generated_images/epoch_028_20251120-235529.png
#   Epoch time: 61.46s, Sampling time: 0.31s
#
# Epoch 29/50
#   Step 0: D_loss=-15.1375 G_loss=-5.5319 W=17.5051 GP=0.2368
#   Step 100: D_loss=-14.4087 G_loss=-6.0022 W=16.9377 GP=0.2529
#   Step 200: D_loss=-15.6869 G_loss=-2.5758 W=18.6813 GP=0.2994
#   Step 300: D_loss=-18.8731 G_loss=-16.3822 W=22.6814 GP=0.3808
#   Step 400: D_loss=-16.9949 G_loss=-17.5482 W=20.5013 GP=0.3506
#   Step 500: D_loss=-14.4104 G_loss=-10.7420 W=16.8196 GP=0.2409
#   Epoch 29 - Avg Critic Loss: -15.6303, Avg Generator Loss: -5.7286
#   Computing KID for epoch 29...
#   [KID] Epoch 29: KID=0.184908 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_029_20251120-235632.png
#   Epoch time: 61.56s, Sampling time: 0.31s
#
# Epoch 30/50
#   Step 0: D_loss=-13.7028 G_loss=-9.1285 W=15.9349 GP=0.2232
#   Step 100: D_loss=-14.1289 G_loss=-1.6080 W=16.1938 GP=0.2065
#   Step 200: D_loss=-16.7559 G_loss=-3.1831 W=20.9545 GP=0.4199
#   Step 300: D_loss=-14.7203 G_loss=-12.5782 W=17.7395 GP=0.3019
#   Step 400: D_loss=-15.6115 G_loss=-0.0008 W=18.6088 GP=0.2997
#   Step 500: D_loss=-15.2709 G_loss=-7.7335 W=18.0032 GP=0.2732
#   Epoch 30 - Avg Critic Loss: -15.8044, Avg Generator Loss: -6.4108
#   Computing KID for epoch 30...
#   [KID] Epoch 30: KID=0.161391 (eval time: 0.61s)
# Saved generated images to generated_images/epoch_030_20251120-235734.png
#   Epoch time: 61.23s, Sampling time: 0.31s
#
# Epoch 31/50
#   Step 0: D_loss=-16.5019 G_loss=-12.5456 W=19.5378 GP=0.3036
#   Step 100: D_loss=-16.2061 G_loss=-12.5115 W=20.0609 GP=0.3855
#   Step 200: D_loss=-14.2603 G_loss=1.4406 W=16.9482 GP=0.2688
#   Step 300: D_loss=-14.8038 G_loss=2.8373 W=17.5796 GP=0.2776
#   Step 400: D_loss=-15.6688 G_loss=-8.7238 W=18.1542 GP=0.2485
#   Step 500: D_loss=-15.3633 G_loss=-3.5571 W=18.2671 GP=0.2904
#   Epoch 31 - Avg Critic Loss: -15.9899, Avg Generator Loss: -6.5241
#   Computing KID for epoch 31...
#   [KID] Epoch 31: KID=0.168741 (eval time: 0.63s)
# Saved generated images to generated_images/epoch_031_20251120-235836.png
#   Epoch time: 61.27s, Sampling time: 0.31s
#
# Epoch 32/50
#   Step 0: D_loss=-15.4287 G_loss=-10.6033 W=18.0670 GP=0.2638
#   Step 100: D_loss=-16.8490 G_loss=-2.4171 W=20.3617 GP=0.3513
#   Step 200: D_loss=-18.1657 G_loss=-5.0406 W=21.5179 GP=0.3352
#   Step 300: D_loss=-15.0228 G_loss=-9.9668 W=17.8696 GP=0.2847
#   Step 400: D_loss=-15.3497 G_loss=-6.7482 W=19.3791 GP=0.4029
#   Step 500: D_loss=-14.9559 G_loss=2.8402 W=17.6157 GP=0.2660
#   Epoch 32 - Avg Critic Loss: -16.2930, Avg Generator Loss: -5.6465
#   Computing KID for epoch 32...
#   [KID] Epoch 32: KID=0.203435 (eval time: 0.64s)
# Saved generated images to generated_images/epoch_032_20251120-235938.png
#   Epoch time: 61.40s, Sampling time: 0.31s
#
# Epoch 33/50
#   Step 0: D_loss=-18.3539 G_loss=-3.2006 W=22.3429 GP=0.3989
#   Step 100: D_loss=-14.2674 G_loss=-6.1585 W=17.2358 GP=0.2968
#   Step 200: D_loss=-17.4884 G_loss=-15.7146 W=20.9243 GP=0.3436
#   Step 300: D_loss=-14.6605 G_loss=-15.9749 W=17.5312 GP=0.2871
#   Step 400: D_loss=-13.3050 G_loss=3.9320 W=15.3593 GP=0.2054
#   Step 500: D_loss=-15.7773 G_loss=-7.7354 W=18.8801 GP=0.3103
#   Epoch 33 - Avg Critic Loss: -16.4557, Avg Generator Loss: -5.6991
#   Computing KID for epoch 33...
#   [KID] Epoch 33: KID=0.169967 (eval time: 0.61s)
# Saved generated images to generated_images/epoch_033_20251121-000040.png
#   Epoch time: 61.17s, Sampling time: 0.31s
#
# Epoch 34/50
#   Step 0: D_loss=-16.3613 G_loss=-1.3351 W=19.3959 GP=0.3035
#   Step 100: D_loss=-17.2665 G_loss=-9.6902 W=20.6105 GP=0.3344
#   Step 200: D_loss=-18.2400 G_loss=-19.6849 W=22.0568 GP=0.3817
#   Step 300: D_loss=-17.9631 G_loss=-16.7492 W=22.2206 GP=0.4257
#   Step 400: D_loss=-16.7114 G_loss=-7.1300 W=20.6433 GP=0.3932
#   Step 500: D_loss=-17.3459 G_loss=-9.6817 W=20.7705 GP=0.3425
#   Epoch 34 - Avg Critic Loss: -16.6591, Avg Generator Loss: -6.0073
#   Computing KID for epoch 34...
#   [KID] Epoch 34: KID=0.135561 (eval time: 0.63s)
# Saved generated images to generated_images/epoch_034_20251121-000143.png
#   Epoch time: 61.57s, Sampling time: 0.31s
#
# Epoch 35/50
#   Step 0: D_loss=-18.2858 G_loss=-20.5557 W=22.7468 GP=0.4461
#   Step 100: D_loss=-16.5404 G_loss=-7.5295 W=19.9723 GP=0.3432
#   Step 200: D_loss=-16.4081 G_loss=-3.2606 W=19.3362 GP=0.2928
#   Step 300: D_loss=-14.9573 G_loss=-0.4636 W=18.1351 GP=0.3178
#   Step 400: D_loss=-16.8142 G_loss=-8.8324 W=20.5241 GP=0.3710
#   Step 500: D_loss=-16.0727 G_loss=-16.9681 W=19.2848 GP=0.3212
#   Epoch 35 - Avg Critic Loss: -16.8897, Avg Generator Loss: -6.5297
#   Computing KID for epoch 35...
#   [KID] Epoch 35: KID=0.170946 (eval time: 0.61s)
# Saved generated images to generated_images/epoch_035_20251121-000246.png
#   Epoch time: 61.74s, Sampling time: 0.31s
#
# Epoch 36/50
#   Step 0: D_loss=-17.4485 G_loss=-16.9279 W=21.1380 GP=0.3690
#   Step 100: D_loss=-15.8854 G_loss=-5.5463 W=18.4559 GP=0.2570
#   Step 200: D_loss=-17.2241 G_loss=-11.9188 W=20.6958 GP=0.3472
#   Step 300: D_loss=-19.2504 G_loss=-14.3207 W=23.2800 GP=0.4030
#   Step 400: D_loss=-16.6470 G_loss=-4.8254 W=21.5784 GP=0.4931
#   Step 500: D_loss=-17.4522 G_loss=-9.4387 W=20.5085 GP=0.3056
#   Epoch 36 - Avg Critic Loss: -17.0741, Avg Generator Loss: -6.6648
#   Computing KID for epoch 36...
#   [KID] Epoch 36: KID=0.151095 (eval time: 0.63s)
# Saved generated images to generated_images/epoch_036_20251121-000348.png
#   Epoch time: 61.34s, Sampling time: 0.31s
#
# Epoch 37/50
#   Step 0: D_loss=-16.6879 G_loss=-11.6098 W=19.4639 GP=0.2776
#   Step 100: D_loss=-16.6568 G_loss=-4.4047 W=20.1430 GP=0.3486
#   Step 200: D_loss=-17.1648 G_loss=-14.1358 W=20.1670 GP=0.3002
#   Step 300: D_loss=-16.1926 G_loss=-9.0341 W=19.7481 GP=0.3556
#   Step 400: D_loss=-16.4744 G_loss=-11.3902 W=19.1443 GP=0.2670
#   Step 500: D_loss=-15.1613 G_loss=-17.9401 W=18.2658 GP=0.3105
#   Epoch 37 - Avg Critic Loss: -17.2502, Avg Generator Loss: -8.0107
#   Computing KID for epoch 37...
#   [KID] Epoch 37: KID=0.166505 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_037_20251121-000450.png
#   Epoch time: 61.33s, Sampling time: 0.31s
#
# Epoch 38/50
#   Step 0: D_loss=-15.4431 G_loss=0.6764 W=18.7795 GP=0.3336
#   Step 100: D_loss=-18.0563 G_loss=-11.4389 W=21.0526 GP=0.2996
#   Step 200: D_loss=-15.6325 G_loss=-6.0370 W=18.9239 GP=0.3291
#   Step 300: D_loss=-16.7969 G_loss=3.3416 W=20.0576 GP=0.3261
#   Step 400: D_loss=-16.0390 G_loss=-2.9678 W=21.3395 GP=0.5300
#   Step 500: D_loss=-18.0406 G_loss=-17.7749 W=21.0340 GP=0.2993
#   Epoch 38 - Avg Critic Loss: -17.3660, Avg Generator Loss: -8.4400
#   Computing KID for epoch 38...
#   [KID] Epoch 38: KID=0.165153 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_038_20251121-000552.png
#   Epoch time: 61.11s, Sampling time: 0.32s
#
# Epoch 39/50
#   Step 0: D_loss=-18.2141 G_loss=-2.0787 W=22.3724 GP=0.4158
#   Step 100: D_loss=-17.3501 G_loss=-5.4660 W=20.2642 GP=0.2914
#   Step 200: D_loss=-18.2437 G_loss=-7.8673 W=21.7083 GP=0.3465
#   Step 300: D_loss=-18.9921 G_loss=-12.3340 W=22.5917 GP=0.3600
#   Step 400: D_loss=-17.5545 G_loss=-10.1548 W=21.2850 GP=0.3731
#   Step 500: D_loss=-17.4290 G_loss=-12.1035 W=21.5467 GP=0.4118
#   Epoch 39 - Avg Critic Loss: -17.6719, Avg Generator Loss: -8.7062
#   Computing KID for epoch 39...
#   [KID] Epoch 39: KID=0.164058 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_039_20251121-000654.png
#   Epoch time: 61.36s, Sampling time: 0.31s
#
# Epoch 40/50
#   Step 0: D_loss=-17.0179 G_loss=-13.5872 W=20.5944 GP=0.3577
#   Step 100: D_loss=-17.1599 G_loss=6.8690 W=21.3380 GP=0.4178
#   Step 200: D_loss=-19.5732 G_loss=-15.0027 W=23.1497 GP=0.3576
#   Step 300: D_loss=-16.2128 G_loss=-7.3997 W=19.9570 GP=0.3744
#   Step 400: D_loss=-16.6365 G_loss=-10.8400 W=21.6429 GP=0.5006
#   Step 500: D_loss=-17.8286 G_loss=-17.3707 W=21.3060 GP=0.3477
#   Epoch 40 - Avg Critic Loss: -17.9504, Avg Generator Loss: -9.1745
#   Computing KID for epoch 40...
#   [KID] Epoch 40: KID=0.133932 (eval time: 0.63s)
# Saved generated images to generated_images/epoch_040_20251121-000758.png
#   Epoch time: 61.66s, Sampling time: 1.07s
#
# Epoch 41/50
#   Step 0: D_loss=-18.5356 G_loss=-15.9454 W=22.2701 GP=0.3734
#   Step 100: D_loss=-19.5388 G_loss=-8.6997 W=24.9584 GP=0.5420
#   Step 200: D_loss=-17.9507 G_loss=-21.1810 W=21.6032 GP=0.3653
#   Step 300: D_loss=-17.9859 G_loss=-8.7723 W=22.1749 GP=0.4189
#   Step 400: D_loss=-19.4419 G_loss=-7.6179 W=23.0449 GP=0.3603
#   Step 500: D_loss=-18.9309 G_loss=2.9009 W=22.2859 GP=0.3355
#   Epoch 41 - Avg Critic Loss: -18.0931, Avg Generator Loss: -9.5969
#   Computing KID for epoch 41...
#   [KID] Epoch 41: KID=0.156836 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_041_20251121-000900.png
#   Epoch time: 61.55s, Sampling time: 0.31s
#
# Epoch 42/50
#   Step 0: D_loss=-19.2736 G_loss=-11.6594 W=22.3390 GP=0.3065
#   Step 100: D_loss=-17.5316 G_loss=-9.9304 W=21.1763 GP=0.3645
#   Step 200: D_loss=-18.3956 G_loss=-13.2060 W=22.1803 GP=0.3785
#   Step 300: D_loss=-17.1970 G_loss=-16.4412 W=20.7009 GP=0.3504
#   Step 400: D_loss=-17.3403 G_loss=-14.9576 W=20.6747 GP=0.3334
#   Step 500: D_loss=-18.1224 G_loss=-14.4906 W=21.2134 GP=0.3091
#   Epoch 42 - Avg Critic Loss: -18.3403, Avg Generator Loss: -10.1311
#   Computing KID for epoch 42...
#   [KID] Epoch 42: KID=0.127613 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_042_20251121-001002.png
#   Epoch time: 61.16s, Sampling time: 0.31s
#
# Epoch 43/50
#   Step 0: D_loss=-16.9571 G_loss=-12.2703 W=20.4353 GP=0.3478
#   Step 100: D_loss=-18.7489 G_loss=-18.0195 W=23.0295 GP=0.4281
#   Step 200: D_loss=-19.5365 G_loss=-16.4355 W=23.5388 GP=0.4002
#   Step 300: D_loss=-19.3796 G_loss=-20.8702 W=23.7062 GP=0.4327
#   Step 400: D_loss=-19.7400 G_loss=-10.8804 W=23.7316 GP=0.3992
#   Step 500: D_loss=-16.7466 G_loss=-18.5726 W=21.7331 GP=0.4987
#   Epoch 43 - Avg Critic Loss: -18.4662, Avg Generator Loss: -10.6843
#   Computing KID for epoch 43...
#   [KID] Epoch 43: KID=0.153926 (eval time: 0.63s)
# Saved generated images to generated_images/epoch_043_20251121-001105.png
#   Epoch time: 61.31s, Sampling time: 0.31s
#
# Epoch 44/50
#   Step 0: D_loss=-18.9549 G_loss=-3.2370 W=22.4161 GP=0.3461
#   Step 100: D_loss=-17.9835 G_loss=-2.0634 W=22.0645 GP=0.4081
#   Step 200: D_loss=-19.2803 G_loss=-14.8983 W=23.4222 GP=0.4142
#   Step 300: D_loss=-17.8737 G_loss=-17.0053 W=21.6665 GP=0.3793
#   Step 400: D_loss=-17.8184 G_loss=-9.0934 W=21.5146 GP=0.3696
#   Step 500: D_loss=-17.9965 G_loss=-14.7332 W=21.8031 GP=0.3807
#   Epoch 44 - Avg Critic Loss: -18.7496, Avg Generator Loss: -11.0405
#   Computing KID for epoch 44...
#   [KID] Epoch 44: KID=0.159629 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_044_20251121-001207.png
#   Epoch time: 61.48s, Sampling time: 0.31s
#
# Epoch 45/50
#   Step 0: D_loss=-22.0033 G_loss=4.6009 W=26.1785 GP=0.4175
#   Step 100: D_loss=-17.1858 G_loss=-9.9478 W=20.2140 GP=0.3028
#   Step 200: D_loss=-19.4671 G_loss=-13.2187 W=23.6106 GP=0.4144
#   Step 300: D_loss=-16.4969 G_loss=-15.6854 W=20.2562 GP=0.3759
#   Step 400: D_loss=-20.8335 G_loss=-19.9685 W=25.4039 GP=0.4570
#   Step 500: D_loss=-18.0115 G_loss=-9.1044 W=22.4193 GP=0.4408
#   Epoch 45 - Avg Critic Loss: -18.9377, Avg Generator Loss: -11.7699
#   Computing KID for epoch 45...
#   [KID] Epoch 45: KID=0.117318 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_045_20251121-001310.png
#   Epoch time: 61.54s, Sampling time: 0.31s
#
# Epoch 46/50
#   Step 0: D_loss=-20.8697 G_loss=-13.1473 W=24.7687 GP=0.3899
#   Step 100: D_loss=-17.4932 G_loss=-5.2485 W=21.6449 GP=0.4152
#   Step 200: D_loss=-17.6644 G_loss=-15.8811 W=21.6973 GP=0.4033
#   Step 300: D_loss=-17.8749 G_loss=-10.1566 W=20.9687 GP=0.3094
#   Step 400: D_loss=-18.1974 G_loss=-1.4896 W=21.5679 GP=0.3370
#   Step 500: D_loss=-20.7068 G_loss=-14.5262 W=25.4732 GP=0.4766
#   Epoch 46 - Avg Critic Loss: -19.1840, Avg Generator Loss: -11.7613
#   Computing KID for epoch 46...
#   [KID] Epoch 46: KID=0.150316 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_046_20251121-001412.png
#   Epoch time: 61.07s, Sampling time: 0.31s
#
# Epoch 47/50
#   Step 0: D_loss=-18.4474 G_loss=-15.1373 W=21.9067 GP=0.3459
#   Step 100: D_loss=-19.4865 G_loss=-19.2116 W=23.2638 GP=0.3777
#   Step 200: D_loss=-20.6364 G_loss=-11.2261 W=25.8656 GP=0.5229
#   Step 300: D_loss=-18.6627 G_loss=-15.7939 W=22.5259 GP=0.3863
#   Step 400: D_loss=-22.3570 G_loss=-21.3364 W=27.8546 GP=0.5498
#   Step 500: D_loss=-20.4154 G_loss=-10.9407 W=25.2477 GP=0.4832
#   Epoch 47 - Avg Critic Loss: -19.3122, Avg Generator Loss: -12.0971
#   Computing KID for epoch 47...
#   [KID] Epoch 47: KID=0.125461 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_047_20251121-001514.png
#   Epoch time: 61.63s, Sampling time: 0.31s
#
# Epoch 48/50
#   Step 0: D_loss=-17.5207 G_loss=-16.0640 W=21.0986 GP=0.3578
#   Step 100: D_loss=-18.8027 G_loss=-6.6341 W=22.3393 GP=0.3537
#   Step 200: D_loss=-20.0226 G_loss=-16.8899 W=24.1926 GP=0.4170
#   Step 300: D_loss=-21.8759 G_loss=-18.8621 W=26.7605 GP=0.4885
#   Step 400: D_loss=-19.7749 G_loss=-12.4763 W=23.8191 GP=0.4044
#   Step 500: D_loss=-19.6503 G_loss=-11.6905 W=23.2604 GP=0.3610
#   Epoch 48 - Avg Critic Loss: -19.5213, Avg Generator Loss: -12.1785
#   Computing KID for epoch 48...
#   [KID] Epoch 48: KID=0.166391 (eval time: 0.62s)
# Saved generated images to generated_images/epoch_048_20251121-001616.png
#   Epoch time: 61.34s, Sampling time: 0.31s
#
# Epoch 49/50
#   Step 0: D_loss=-17.9590 G_loss=-11.9004 W=21.9544 GP=0.3995
#   Step 100: D_loss=-16.9586 G_loss=-6.2394 W=20.6371 GP=0.3678
#   Step 200: D_loss=-21.8620 G_loss=-12.6549 W=26.7835 GP=0.4921
#   Step 300: D_loss=-20.2252 G_loss=-13.9986 W=25.8170 GP=0.5592
#   Step 400: D_loss=-18.1271 G_loss=-7.3149 W=22.2953 GP=0.4168
#   Step 500: D_loss=-19.0908 G_loss=-21.8123 W=23.5351 GP=0.4444
#   Epoch 49 - Avg Critic Loss: -19.7562, Avg Generator Loss: -13.1960
#   Computing KID for epoch 49...
#   [KID] Epoch 49: KID=0.147259 (eval time: 0.63s)
# Saved generated images to generated_images/epoch_049_20251121-001719.png
#   Epoch time: 61.45s, Sampling time: 0.31s
#
# Epoch 50/50
#   Step 0: D_loss=-22.0871 G_loss=-12.8692 W=26.8477 GP=0.4761
#   Step 100: D_loss=-18.9956 G_loss=-18.0489 W=24.1409 GP=0.5145
#   Step 200: D_loss=-19.0765 G_loss=-15.3795 W=23.1865 GP=0.4110
#   Step 300: D_loss=-18.7955 G_loss=-4.8923 W=23.3025 GP=0.4507
#   Step 400: D_loss=-19.4920 G_loss=-12.4106 W=23.3247 GP=0.3833
#   Step 500: D_loss=-19.3127 G_loss=-9.3135 W=23.5306 GP=0.4218
#   Epoch 50 - Avg Critic Loss: -19.8786, Avg Generator Loss: -14.5892
#   Computing KID for epoch 50...
#   [KID] Epoch 50: KID=0.118487 (eval time: 0.61s)
# Saved generated images to generated_images/epoch_050_20251121-001821.png
#   Epoch time: 61.55s, Sampling time: 0.31s

# %%
# Calculate total training time
total_training_time = time.time() - training_start_time
print(f"\nTotal training time: {total_training_time:.2f} seconds ({total_training_time/60:.2f} minutes)")

# Save models
print("\nSaving models...")
os.makedirs("checkpoints", exist_ok=True)
generator.save_weights("checkpoints/wgan_generator.weights.h5")
critic.save_weights("checkpoints/wgan_critic.weights.h5")
print("Models saved!")

# ---- Save metrics history to compare with DDIM ----
import json

# Save as JSON (full data)
with open("wgan_metrics.json", "w") as f:
    json.dump(kid_history, f, indent=2)

# Save as CSV with specific column order: epoch, KID, training time, sampling time
df_metrics = pd.DataFrame(kid_history)
# Reorder columns for the CSV
df_csv = df_metrics[['epoch', 'kid', 'epoch_train_time_sec', 'sampling_time_sec']].copy()
# Rename columns for clarity
df_csv.columns = ['Epoch', 'KID', 'Training_Time_Sec', 'Sampling_Time_Sec']
df_csv.to_csv("wgan_metrics.csv", index=False)

# Print summary statistics
print("\n" + "="*60)
print("TRAINING SUMMARY")
print("="*60)
print(f"Total training time: {total_training_time:.2f}s ({total_training_time/60:.2f} min)")
print(f"Average epoch time: {df_metrics['epoch_train_time_sec'].mean():.2f}s")
print(f"Average sampling time: {df_metrics['sampling_time_sec'].mean():.2f}s")
print(f"Average KID eval time: {df_metrics['kid_eval_time_sec'].mean():.2f}s")
print(f"\nFinal KID: {df_metrics['kid'].iloc[-1]:.6f}")
print(f"Best KID: {df_metrics['kid'].min():.6f} (Epoch {df_metrics.loc[df_metrics['kid'].idxmin(), 'epoch']:.0f})")
print("="*60)
print(f"\nMetrics saved to:")
print(f"  - wgan_metrics.csv")
print(f"  - wgan_metrics.json")
print("\nTraining complete!")
# Out:
# Total training time: 3134.56 seconds (52.24 minutes)
#
# Saving models...
# Models saved!
#
# ============================================================
# TRAINING SUMMARY
# ============================================================
# Total training time: 3134.56s (52.24 min)
# Average epoch time: 61.71s
# Average sampling time: 0.35s
# Average KID eval time: 0.63s
#
# Final KID: 0.118487
# Best KID: 0.117318 (Epoch 45)
# ============================================================
#
# Metrics saved to:
#   - wgan_metrics.csv
#   - wgan_metrics.json
#
# Training complete!

# %%
# Generate final high-quality images after training
print("Generating final images...")

# Create output directory
final_output_dir = "final_generated_images"
os.makedirs(final_output_dir, exist_ok=True)

# Generate multiple sets of images
num_sets = 5  # Generate 5 sets of 16 images each
num_images_per_set = 16

for set_idx in range(num_sets):
    # Generate random noise
    noise = tf.random.normal((num_images_per_set, latent_dim))

    # Generate images using EMA generator (best quality)
    generated_images = G_ema(noise, training=False)

    # Convert from [-1, 1] to [0, 1] for display
    generated_images = (generated_images + 1) / 2.0
    generated_images = ops.clip(generated_images, 0.0, 1.0)

    # Plot grid (4x4)
    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    for i, ax in enumerate(axes.flat):
        ax.imshow(generated_images[i].numpy())
        ax.axis('off')
    plt.tight_layout()

    # Save figure
    timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
    filename = f"final_set_{set_idx+1}_{timestamp}.png"
    filepath = os.path.join(final_output_dir, filename)
    plt.savefig(filepath, dpi=150, bbox_inches='tight')
    plt.close()

    print(f"  Saved set {set_idx+1}/{num_sets} to {filepath}")

print(f"\n✓ Generated {num_sets} sets of images in '{final_output_dir}/' folder")
print(f"Total images: {num_sets * num_images_per_set} images")
# Out:
# Generating final images...
#   Saved set 1/5 to final_generated_images/final_set_1_20251121-001822.png
#   Saved set 2/5 to final_generated_images/final_set_2_20251121-001822.png
#   Saved set 3/5 to final_generated_images/final_set_3_20251121-001822.png
#   Saved set 4/5 to final_generated_images/final_set_4_20251121-001823.png
#   Saved set 5/5 to final_generated_images/final_set_5_20251121-001823.png
#
# ✓ Generated 5 sets of images in 'final_generated_images/' folder
# Total images: 80 images

# %%
    # !zip -r generated_images.zip generated_images
# Out:
#   adding: generated_images/ (stored 0%)
#   adding: generated_images/epoch_042_20251121-001002.png (deflated 4%)
#   adding: generated_images/epoch_006_20251120-233233.png (deflated 5%)
#   adding: generated_images/epoch_030_20251120-235734.png (deflated 4%)
#   adding: generated_images/epoch_048_20251121-001616.png (deflated 4%)
#   adding: generated_images/epoch_037_20251121-000450.png (deflated 4%)
#   adding: generated_images/epoch_012_20251120-233849.png (deflated 4%)
#   adding: generated_images/epoch_046_20251121-001412.png (deflated 4%)
#   adding: generated_images/epoch_020_20251120-234709.png (deflated 4%)
#   adding: generated_images/epoch_049_20251121-001719.png (deflated 4%)
#   adding: generated_images/epoch_039_20251121-000654.png (deflated 4%)
#   adding: generated_images/epoch_007_20251120-233336.png (deflated 4%)
#   adding: generated_images/epoch_029_20251120-235632.png (deflated 4%)
#   adding: generated_images/epoch_038_20251121-000552.png (deflated 4%)
#   adding: generated_images/epoch_015_20251120-234156.png (deflated 4%)
#   adding: generated_images/epoch_040_20251121-000758.png (deflated 4%)
#   adding: generated_images/epoch_003_20251120-232926.png (deflated 5%)
#   adding: generated_images/epoch_009_20251120-233540.png (deflated 4%)
#   adding: generated_images/epoch_025_20251120-235222.png (deflated 4%)
#   adding: generated_images/epoch_018_20251120-234504.png (deflated 4%)
#   adding: generated_images/epoch_036_20251121-000348.png (deflated 4%)
#   adding: generated_images/epoch_023_20251120-235016.png (deflated 4%)
#   adding: generated_images/epoch_008_20251120-233438.png (deflated 4%)
#   adding: generated_images/epoch_019_20251120-234607.png (deflated 4%)
#   adding: generated_images/epoch_014_20251120-234054.png (deflated 4%)
#   adding: generated_images/epoch_010_20251120-233643.png (deflated 4%)
#   adding: generated_images/epoch_004_20251120-233028.png (deflated 5%)
#   adding: generated_images/epoch_024_20251120-235120.png (deflated 4%)
#   adding: generated_images/epoch_034_20251121-000143.png (deflated 4%)
#   adding: generated_images/epoch_045_20251121-001310.png (deflated 4%)
#   adding: generated_images/epoch_031_20251120-235836.png (deflated 4%)
#   adding: generated_images/epoch_027_20251120-235427.png (deflated 4%)
#   adding: generated_images/epoch_041_20251121-000900.png (deflated 4%)
#   adding: generated_images/epoch_005_20251120-233131.png (deflated 5%)
#   adding: generated_images/epoch_035_20251121-000246.png (deflated 4%)
#   adding: generated_images/epoch_022_20251120-234914.png (deflated 4%)
#   adding: generated_images/epoch_032_20251120-235938.png (deflated 4%)
#   adding: generated_images/epoch_043_20251121-001105.png (deflated 4%)
#   adding: generated_images/epoch_021_20251120-234812.png (deflated 4%)
#   adding: generated_images/epoch_011_20251120-233746.png (deflated 4%)
#   adding: generated_images/epoch_002_20251120-232823.png (deflated 5%)
#   adding: generated_images/epoch_033_20251121-000040.png (deflated 4%)
#   adding: generated_images/epoch_047_20251121-001514.png (deflated 4%)
#   adding: generated_images/epoch_016_20251120-234259.png (deflated 4%)
#   adding: generated_images/epoch_001_20251120-232721.png (deflated 5%)
#   adding: generated_images/epoch_050_20251121-001821.png (deflated 4%)
#   adding: generated_images/epoch_044_20251121-001207.png (deflated 4%)
#   adding: generated_images/epoch_028_20251120-235529.png (deflated 4%)
#   adding: generated_images/epoch_013_20251120-233951.png (deflated 5%)
#   adding: generated_images/epoch_017_20251120-234402.png (deflated 4%)
#   adding: generated_images/epoch_026_20251120-235324.png (deflated 4%)

# %%
    from google.colab import files
    files.download('generated_images.zip')

# %%
    # !zip -r final_generated_images.zip final_generated_images
# Out:
#   adding: final_generated_images/ (stored 0%)
#   adding: final_generated_images/final_set_4_20251121-001823.png (deflated 8%)
#   adding: final_generated_images/final_set_3_20251121-001822.png (deflated 7%)
#   adding: final_generated_images/final_set_1_20251121-001822.png (deflated 8%)
#   adding: final_generated_images/final_set_5_20251121-001823.png (deflated 7%)
#   adding: final_generated_images/final_set_2_20251121-001822.png (deflated 8%)

# %%
  files.download('final_generated_images.zip')
